# %%
from google.colab import files
src = list(files.upload().values())[0]
open('replay_buffer.py','wb').write(src)
import replay_buffer
# Out:
#      <input type="file" id="files-4456c32c-365a-4e73-a83e-8fca1a1fa1d4" name="files[]" multiple disabled />
#      <output id="result-4456c32c-365a-4e73-a83e-8fca1a1fa1d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving replay_buffer.py to replay_buffer.py

# %%
from replay_buffer import ReplayBuffer

# %%
import tensorflow as tf
import numpy as np
import gym
from gym import wrappers
import tflearn
import argparse
import pprint as pp

# %%
# ===========================
#   Actor and Critic DNNs
# ===========================

class ActorNetwork(object):
    """
    Input to the network is the state, output is the action
    under a deterministic policy.

    The output layer activation is a tanh to keep the action
    between -action_bound and action_bound
    """

    def __init__(self, sess, state_dim, action_dim, action_bound, learning_rate, tau, batch_size):
        self.sess = sess
        self.s_dim = state_dim
        self.a_dim = action_dim
        self.action_bound = action_bound
        self.learning_rate = learning_rate
        self.tau = tau
        self.batch_size = batch_size

        # Actor Network
        self.inputs, self.out, self.scaled_out = self.create_actor_network()

        self.network_params = tf.trainable_variables()

        # Target Network
        self.target_inputs, self.target_out, self.target_scaled_out = self.create_actor_network()

        self.target_network_params = tf.trainable_variables()[
            len(self.network_params):]

        # Op for periodically updating target network with online network
        # weights
        self.update_target_network_params = \
            [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) +
                                                  tf.multiply(self.target_network_params[i], 1. - self.tau))
                for i in range(len(self.target_network_params))]

        # This gradient will be provided by the critic network
        self.action_gradient = tf.placeholder(tf.float32, [None, self.a_dim])

        # Combine the gradients here
        self.unnormalized_actor_gradients = tf.gradients(
            self.scaled_out, self.network_params, -self.action_gradient)
        self.actor_gradients = list(map(lambda x: tf.div(x, self.batch_size), self.unnormalized_actor_gradients))

        # Optimization Op
        self.optimize = tf.train.AdamOptimizer(self.learning_rate).\
            apply_gradients(zip(self.actor_gradients, self.network_params))

        self.num_trainable_vars = len(
            self.network_params) + len(self.target_network_params)

    def create_actor_network(self):
        inputs = tflearn.input_data(shape=[None, self.s_dim])
        net = tflearn.fully_connected(inputs, 400)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)
        net = tflearn.fully_connected(net, 300)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)
        # Final layer weights are init to Uniform[-3e-3, 3e-3]
        w_init = tflearn.initializations.uniform(minval=-0.003, maxval=0.003)
        out = tflearn.fully_connected(
            net, self.a_dim, activation='tanh', weights_init=w_init)
        # Scale output to -action_bound to action_bound
        scaled_out = tf.multiply(out, self.action_bound)
        return inputs, out, scaled_out

    def train(self, inputs, a_gradient):
        self.sess.run(self.optimize, feed_dict={
            self.inputs: inputs,
            self.action_gradient: a_gradient
        })

    def predict(self, inputs):
        return self.sess.run(self.scaled_out, feed_dict={
            self.inputs: inputs
        })

    def predict_target(self, inputs):
        return self.sess.run(self.target_scaled_out, feed_dict={
            self.target_inputs: inputs
        })

    def update_target_network(self):
        self.sess.run(self.update_target_network_params)

    def get_num_trainable_vars(self):
        return self.num_trainable_vars


class CriticNetwork(object):
    """
    Input to the network is the state and action, output is Q(s,a).
    The action must be obtained from the output of the Actor network.

    """

    def __init__(self, sess, state_dim, action_dim, learning_rate, tau, gamma, num_actor_vars):
        self.sess = sess
        self.s_dim = state_dim
        self.a_dim = action_dim
        self.learning_rate = learning_rate
        self.tau = tau
        self.gamma = gamma

        # Create the critic network
        self.inputs, self.action, self.out = self.create_critic_network()

        self.network_params = tf.trainable_variables()[num_actor_vars:]

        # Target Network
        self.target_inputs, self.target_action, self.target_out = self.create_critic_network()

        self.target_network_params = tf.trainable_variables()[(len(self.network_params) + num_actor_vars):]

        # Op for periodically updating target network with online network
        # weights with regularization
        self.update_target_network_params = \
            [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) \
            + tf.multiply(self.target_network_params[i], 1. - self.tau))
                for i in range(len(self.target_network_params))]

        # Network target (y_i)
        self.predicted_q_value = tf.placeholder(tf.float32, [None, 1])

        # Define loss and optimization Op
        self.loss = tflearn.mean_square(self.predicted_q_value, self.out)
        self.optimize = tf.train.AdamOptimizer(
            self.learning_rate).minimize(self.loss)

        # Get the gradient of the net w.r.t. the action.
        # For each action in the minibatch (i.e., for each x in xs),
        # this will sum up the gradients of each critic output in the minibatch
        # w.r.t. that action. Each output is independent of all
        # actions except for one.
        self.action_grads = tf.gradients(self.out, self.action)

    def create_critic_network(self):
        inputs = tflearn.input_data(shape=[None, self.s_dim])
        action = tflearn.input_data(shape=[None, self.a_dim])
        net = tflearn.fully_connected(inputs, 400)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)

        # Add the action tensor in the 2nd hidden layer
        # Use two temp layers to get the corresponding weights and biases
        t1 = tflearn.fully_connected(net, 300)
        t2 = tflearn.fully_connected(action, 300)

        net = tflearn.activation(
            tf.matmul(net, t1.W) + tf.matmul(action, t2.W) + t2.b, activation='relu')

        # linear layer connected to 1 output representing Q(s,a)
        # Weights are init to Uniform[-3e-3, 3e-3]
        w_init = tflearn.initializations.uniform(minval=-0.003, maxval=0.003)
        out = tflearn.fully_connected(net, 1, weights_init=w_init)
        return inputs, action, out

    def train(self, inputs, action, predicted_q_value):
        return self.sess.run([self.out, self.optimize], feed_dict={
            self.inputs: inputs,
            self.action: action,
            self.predicted_q_value: predicted_q_value
        })

    def predict(self, inputs, action):
        return self.sess.run(self.out, feed_dict={
            self.inputs: inputs,
            self.action: action
        })

    def predict_target(self, inputs, action):
        return self.sess.run(self.target_out, feed_dict={
            self.target_inputs: inputs,
            self.target_action: action
        })

    def action_gradients(self, inputs, actions):
        return self.sess.run(self.action_grads, feed_dict={
            self.inputs: inputs,
            self.action: actions
        })

    def update_target_network(self):
        self.sess.run(self.update_target_network_params)
        
    

# Taken from https://github.com/openai/baselines/blob/master/baselines/ddpg/noise.py, which is
# based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckActionNoise:
    def __init__(self, mu, sigma=0.3, theta=.15, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

# ===========================
#   Tensorflow Summary Ops
# ===========================

def build_summaries():
    episode_reward = tf.Variable(0.)
    tf.summary.scalar("Reward", episode_reward)
    episode_ave_max_q = tf.Variable(0.)
    tf.summary.scalar("Qmax Value", episode_ave_max_q)

    summary_vars = [episode_reward, episode_ave_max_q]
    summary_ops = tf.summary.merge_all()

    return summary_ops, summary_vars

# ===========================
#   Agent Training
# ===========================

def train(sess, env, args, actor, critic, actor_noise, D_DDPG_flag, 
          target_hard_copy_flag, target_hard_copy_interval):

    # Set up summary Ops
    summary_ops, summary_vars = build_summaries()

    sess.run(tf.global_variables_initializer())
    writer = tf.summary.FileWriter(args['summary_dir'], sess.graph)

    # Initialize target network weights
    actor.update_target_network()
    critic.update_target_network()

    # Initialize replay memory
    replay_buffer = ReplayBuffer(int(args['buffer_size']), int(args['random_seed']))

    # Needed to enable BatchNorm. 
    # This hurts the performance on Pendulum but could be useful
    # in other environments.
    # tflearn.is_training(True)

    for i in range(int(args['max_episodes'])):

        s = env.reset()

        ep_reward = 0
        ep_ave_max_q = 0

        for j in range(int(args['max_episode_len'])):

            if args['render_env']:
                env.render()

            # Added exploration noise
            #a = actor.predict(np.reshape(s, (1, 3))) + (1. / (1. + i))
            a = actor.predict(np.reshape(s, (1, actor.s_dim))) + actor_noise()

            s2, r, terminal, info = env.step(a[0])

            replay_buffer.add(np.reshape(s, (actor.s_dim,)), np.reshape(a, (actor.a_dim,)), r,
                              terminal, np.reshape(s2, (actor.s_dim,)))

            # Keep adding experience to the memory until
            # there are at least minibatch size samples
            if replay_buffer.size() > int(args['minibatch_size']):
                s_batch, a_batch, r_batch, t_batch, s2_batch = \
                    replay_buffer.sample_batch(int(args['minibatch_size']))

                if D_DDPG_flag == True:
                    # Calculate targets: Double DDPG
                    target_q = critic.predict_target(
                            s2_batch, actor.predict(s2_batch))
                else:
                    # Calculate targets
                    target_q = critic.predict_target(
                            s2_batch, actor.predict_target(s2_batch))
                
                

                y_i = []
                for k in range(int(args['minibatch_size'])):
                    if t_batch[k]:
                        y_i.append(r_batch[k])
                    else:
                        y_i.append(r_batch[k] + critic.gamma * target_q[k])

                # Update the critic given the targets
                predicted_q_value, _ = critic.train(
                    s_batch, a_batch, np.reshape(y_i, (int(args['minibatch_size']), 1)))

                ep_ave_max_q += np.amax(predicted_q_value)

                # Update the actor policy using the sampled gradient
                a_outs = actor.predict(s_batch)
                grads = critic.action_gradients(s_batch, a_outs)
                actor.train(s_batch, grads[0])
                
                # Update target networks
                if target_hard_copy_flag == True:
                    if j % target_hard_copy_interval == 0:
                        actor.update_target_network()
                        critic.update_target_network()
                else:
                    actor.update_target_network()
                    critic.update_target_network()

            s = s2
            ep_reward += r

            if terminal:

                summary_str = sess.run(summary_ops, feed_dict={
                    summary_vars[0]: ep_reward,
                    summary_vars[1]: ep_ave_max_q / float(j)
                })

                writer.add_summary(summary_str, i)
                writer.flush()

                print('| Reward: {:d} | Episode: {:d} | Qmax: {:.4f}'.format(int(ep_reward), \
                        i, (ep_ave_max_q / float(j))))
                break

# %%
def main(args):

    with tf.Session() as sess:

        env = gym.make(args['env'])
        np.random.seed(int(args['random_seed']))
        tf.set_random_seed(int(args['random_seed']))
        env.seed(int(args['random_seed']))

        state_dim = env.observation_space.shape[0]
        action_dim = env.action_space.shape[0]
        action_bound = env.action_space.high
        # Ensure action bound is symmetric
        assert (env.action_space.high == -env.action_space.low)
        
        if args['target_hard_copy_flag'] == True:
            args['tau'] = 1.0

        actor = ActorNetwork(sess, state_dim, action_dim, action_bound,
                             float(args['actor_lr']), float(args['tau']),
                             int(args['minibatch_size']))

        critic = CriticNetwork(sess, state_dim, action_dim,
                               float(args['critic_lr']), float(args['tau']),
                               float(args['gamma']),
                               actor.get_num_trainable_vars())
        
        actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

        if args['use_gym_monitor']:
            if not args['render_env']:
                env = wrappers.Monitor(
                    env, args['monitor_dir'], video_callable=False, force=True)
            else:
                env = wrappers.Monitor(env, args['monitor_dir'], force=True)

        train(sess, env, args, actor, critic, actor_noise, args['double_ddpg_flag'], 
              args['target_hard_copy_flag'], args['target_hard_copy_interval'])

        if args['use_gym_monitor']:
            env.monitor.close()

# %%
args = {'actor_lr': 0.0001,
        'critic_lr': 0.001,
        'gamma': 0.99,
        'tau': 0.001,
        'buffer_size': 1000000,
        'minibatch_size': 64,

        'double_ddpg_flag': False,
        'target_hard_copy_flag': True,
        'target_hard_copy_interval': 20,

        'env': 'Pendulum-v0',
        'random_seed': 1234,
        'max_episodes': 50000,
        'max_episode_len': 1000,
        'render_env': False,
        'use_gym_monitor': True,
        'monitor_dir': './results/gym_ddpg',
        'summary_dir': './results/tf_ddpg/ddpg_hard_20_run1'}
  
pp.pprint(args)

main(args)
# Out:
# {'actor_lr': 0.0001,
#  'buffer_size': 1000000,
#  'critic_lr': 0.001,
#  'double_ddpg_flag': False,
#  'env': 'Pendulum-v0',
#  'gamma': 0.99,
#  'max_episode_len': 1000,
#  'max_episodes': 50000,
#  'minibatch_size': 64,
#  'monitor_dir': './results/gym_ddpg',
#  'random_seed': 1234,
#  'render_env': False,
#  'summary_dir': './results/tf_ddpg/ddpg_hard_20_run1',
#  'target_hard_copy_flag': True,
#  'target_hard_copy_interval': 20,
#  'tau': 0.001,
#  'use_gym_monitor': True}
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# INFO:tensorflow:Summary name Qmax Value is illegal; using Qmax_Value instead.
# WARNING:tensorflow:Issue encountered when serializing data_preprocessing.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'NoneType' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing data_augmentation.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'NoneType' object has no attribute 'name'
# | Reward: -1106 | Episode: 0 | Qmax: -1.0548
# | Reward: -1772 | Episode: 1 | Qmax: -20.2838
# | Reward: -1634 | Episode: 2 | Qmax: -86.9384
# | Reward: -1499 | Episode: 3 | Qmax: -133.0212
# | Reward: -1493 | Episode: 4 | Qmax: -156.1495
# | Reward: -1102 | Episode: 5 | Qmax: -211.0318
# | Reward: -1152 | Episode: 6 | Qmax: -241.4040
# | Reward: -1601 | Episode: 7 | Qmax: -256.0466
# | Reward: -1446 | Episode: 8 | Qmax: -279.7107
# | Reward: -1469 | Episode: 9 | Qmax: -304.5845
# | Reward: -1481 | Episode: 10 | Qmax: -302.0259
# | Reward: -1062 | Episode: 11 | Qmax: -297.7071
# | Reward: -1251 | Episode: 12 | Qmax: -333.4321
# | Reward: -1229 | Episode: 13 | Qmax: -351.2468
# | Reward: -1060 | Episode: 14 | Qmax: -345.8857
# | Reward: -1376 | Episode: 15 | Qmax: -365.0187
# | Reward: -1366 | Episode: 16 | Qmax: -365.6057
# | Reward: -1537 | Episode: 17 | Qmax: -367.4253
# | Reward: -1470 | Episode: 18 | Qmax: -355.3757
# | Reward: -1251 | Episode: 19 | Qmax: -374.5990
# | Reward: -1196 | Episode: 20 | Qmax: -375.5014
# | Reward: -1544 | Episode: 21 | Qmax: -373.2751
# | Reward: -1268 | Episode: 22 | Qmax: -382.1774
# | Reward: -907 | Episode: 23 | Qmax: -389.9126
# | Reward: -1460 | Episode: 24 | Qmax: -364.5283
# | Reward: -1348 | Episode: 25 | Qmax: -380.6380
# | Reward: -1456 | Episode: 26 | Qmax: -373.5029
# | Reward: -1540 | Episode: 27 | Qmax: -381.6403
# | Reward: -1135 | Episode: 28 | Qmax: -388.2242
# | Reward: -1520 | Episode: 29 | Qmax: -387.0463
# | Reward: -1360 | Episode: 30 | Qmax: -390.3739
# | Reward: -1404 | Episode: 31 | Qmax: -419.0098
# | Reward: -1461 | Episode: 32 | Qmax: -434.8483
# | Reward: -1170 | Episode: 33 | Qmax: -436.9357
# | Reward: -1521 | Episode: 34 | Qmax: -418.3630
# | Reward: -1524 | Episode: 35 | Qmax: -413.8887
# | Reward: -1084 | Episode: 36 | Qmax: -405.6226
# | Reward: -1498 | Episode: 37 | Qmax: -404.8292
# | Reward: -1598 | Episode: 38 | Qmax: -402.4185
# | Reward: -1507 | Episode: 39 | Qmax: -410.9705
# | Reward: -1627 | Episode: 40 | Qmax: -415.9275
# | Reward: -1554 | Episode: 41 | Qmax: -424.9101
# | Reward: -1646 | Episode: 42 | Qmax: -410.7174
# | Reward: -1652 | Episode: 43 | Qmax: -396.6043
# | Reward: -1577 | Episode: 44 | Qmax: -404.1306
# | Reward: -979 | Episode: 45 | Qmax: -418.6330
# | Reward: -1365 | Episode: 46 | Qmax: -444.1515
# | Reward: -1489 | Episode: 47 | Qmax: -417.3744
# | Reward: -1332 | Episode: 48 | Qmax: -405.0261
# | Reward: -1508 | Episode: 49 | Qmax: -408.6960
# | Reward: -1373 | Episode: 50 | Qmax: -402.3150
# | Reward: -1497 | Episode: 51 | Qmax: -435.8946
# | Reward: -1369 | Episode: 52 | Qmax: -411.3744
# | Reward: -1506 | Episode: 53 | Qmax: -421.6388
# | Reward: -1501 | Episode: 54 | Qmax: -404.5527
# | Reward: -1505 | Episode: 55 | Qmax: -412.6056
# | Reward: -1597 | Episode: 56 | Qmax: -402.7784
# | Reward: -1526 | Episode: 57 | Qmax: -401.1668
# | Reward: -1502 | Episode: 58 | Qmax: -397.9880
# | Reward: -1610 | Episode: 59 | Qmax: -400.4562
# | Reward: -1636 | Episode: 60 | Qmax: -384.0307
# | Reward: -1619 | Episode: 61 | Qmax: -371.5719
# | Reward: -1562 | Episode: 62 | Qmax: -362.1229
# | Reward: -1502 | Episode: 63 | Qmax: -385.9172
# | Reward: -1648 | Episode: 64 | Qmax: -367.5542
# | Reward: -1555 | Episode: 65 | Qmax: -367.0402
# | Reward: -1608 | Episode: 66 | Qmax: -363.4696
# | Reward: -1603 | Episode: 67 | Qmax: -363.4248
# | Reward: -1645 | Episode: 68 | Qmax: -375.8084
# | Reward: -1569 | Episode: 69 | Qmax: -374.4356
# | Reward: -1506 | Episode: 70 | Qmax: -381.2049
# | Reward: -1474 | Episode: 71 | Qmax: -372.1106
# | Reward: -1505 | Episode: 72 | Qmax: -376.0466
# | Reward: -1629 | Episode: 73 | Qmax: -384.7499
# | Reward: -1590 | Episode: 74 | Qmax: -387.1678
# | Reward: -1501 | Episode: 75 | Qmax: -381.4699
# | Reward: -1637 | Episode: 76 | Qmax: -379.5966
# | Reward: -1584 | Episode: 77 | Qmax: -375.0261
# | Reward: -1533 | Episode: 78 | Qmax: -377.9663
# | Reward: -1555 | Episode: 79 | Qmax: -385.3909
# | Reward: -1599 | Episode: 80 | Qmax: -392.6410
# | Reward: -1538 | Episode: 81 | Qmax: -410.7906
# | Reward: -1598 | Episode: 82 | Qmax: -402.5149
# | Reward: -1528 | Episode: 83 | Qmax: -407.9263
# | Reward: -1347 | Episode: 84 | Qmax: -412.4315
# | Reward: -1542 | Episode: 85 | Qmax: -410.8939
# | Reward: -1393 | Episode: 86 | Qmax: -391.2884
# | Reward: -1618 | Episode: 87 | Qmax: -399.3259
# | Reward: -1084 | Episode: 88 | Qmax: -396.3891
# | Reward: -1146 | Episode: 89 | Qmax: -397.2979
# | Reward: -1627 | Episode: 90 | Qmax: -406.2448
# | Reward: -1570 | Episode: 91 | Qmax: -391.4017
# | Reward: -1175 | Episode: 92 | Qmax: -406.1806
# | Reward: -1653 | Episode: 93 | Qmax: -398.1374
# | Reward: -1635 | Episode: 94 | Qmax: -426.1918
# | Reward: -1634 | Episode: 95 | Qmax: -425.8765
# | Reward: -1584 | Episode: 96 | Qmax: -447.2302
# | Reward: -1576 | Episode: 97 | Qmax: -443.6731
# | Reward: -1649 | Episode: 98 | Qmax: -420.3090
# | Reward: -1654 | Episode: 99 | Qmax: -426.6189
# | Reward: -1347 | Episode: 100 | Qmax: -414.3285
# | Reward: -1643 | Episode: 101 | Qmax: -421.0858
# | Reward: -1539 | Episode: 102 | Qmax: -405.4528
# | Reward: -1648 | Episode: 103 | Qmax: -408.5252
# | Reward: -1640 | Episode: 104 | Qmax: -403.4818
# | Reward: -1597 | Episode: 105 | Qmax: -395.4815
# | Reward: -1657 | Episode: 106 | Qmax: -375.1432
# | Reward: -1514 | Episode: 107 | Qmax: -384.8412
# | Reward: -1652 | Episode: 108 | Qmax: -393.4805
# | Reward: -1632 | Episode: 109 | Qmax: -400.1207
# | Reward: -1609 | Episode: 110 | Qmax: -389.2758
# | Reward: -1577 | Episode: 111 | Qmax: -389.7077
# | Reward: -1547 | Episode: 112 | Qmax: -393.5176
# | Reward: -1528 | Episode: 113 | Qmax: -392.1257
# | Reward: -1638 | Episode: 114 | Qmax: -400.3297
# | Reward: -1518 | Episode: 115 | Qmax: -414.0481
# | Reward: -1617 | Episode: 116 | Qmax: -430.7187
# | Reward: -1497 | Episode: 117 | Qmax: -425.1774
# | Reward: -1624 | Episode: 118 | Qmax: -432.0208
# | Reward: -1471 | Episode: 119 | Qmax: -419.5878
# | Reward: -1468 | Episode: 120 | Qmax: -411.3734
# | Reward: -989 | Episode: 121 | Qmax: -413.9137
# | Reward: -1492 | Episode: 122 | Qmax: -406.4941
# | Reward: -951 | Episode: 123 | Qmax: -411.8699
# | Reward: -1583 | Episode: 124 | Qmax: -429.1973
# | Reward: -1507 | Episode: 125 | Qmax: -425.9037
# | Reward: -1601 | Episode: 126 | Qmax: -412.9337
# | Reward: -1652 | Episode: 127 | Qmax: -413.4917
# | Reward: -1641 | Episode: 128 | Qmax: -401.2569
# | Reward: -1605 | Episode: 129 | Qmax: -423.2628
# | Reward: -1543 | Episode: 130 | Qmax: -432.2686
# | Reward: -1655 | Episode: 131 | Qmax: -442.7065
# | Reward: -1559 | Episode: 132 | Qmax: -433.5518
# | Reward: -1588 | Episode: 133 | Qmax: -421.3312
# | Reward: -1531 | Episode: 134 | Qmax: -419.4578
# | Reward: -1576 | Episode: 135 | Qmax: -430.4173
# | Reward: -1649 | Episode: 136 | Qmax: -432.8580
# | Reward: -1622 | Episode: 137 | Qmax: -421.8480
# | Reward: -1607 | Episode: 138 | Qmax: -435.1174
# | Reward: -1511 | Episode: 139 | Qmax: -397.6985
# | Reward: -1650 | Episode: 140 | Qmax: -403.4178
# | Reward: -1532 | Episode: 141 | Qmax: -396.0041
# | Reward: -1646 | Episode: 142 | Qmax: -395.7016
# | Reward: -1496 | Episode: 143 | Qmax: -409.2639
# | Reward: -1454 | Episode: 144 | Qmax: -422.7731
# | Reward: -1553 | Episode: 145 | Qmax: -434.5609
# | Reward: -1496 | Episode: 146 | Qmax: -437.9610
# | Reward: -1517 | Episode: 147 | Qmax: -444.3314
# | Reward: -1509 | Episode: 148 | Qmax: -426.0659
# | Reward: -1502 | Episode: 149 | Qmax: -425.1918
# | Reward: -1404 | Episode: 150 | Qmax: -418.1098
# | Reward: -1589 | Episode: 151 | Qmax: -410.3934
# | Reward: -1590 | Episode: 152 | Qmax: -433.0000
# | Reward: -1609 | Episode: 153 | Qmax: -423.6378
# | Reward: -1503 | Episode: 154 | Qmax: -420.2705
# | Reward: -1515 | Episode: 155 | Qmax: -401.6051
# | Reward: -1296 | Episode: 156 | Qmax: -419.3889
# | Reward: -1613 | Episode: 157 | Qmax: -402.1089
# | Reward: -1565 | Episode: 158 | Qmax: -417.5574
# | Reward: -1581 | Episode: 159 | Qmax: -400.4936
# | Reward: -1306 | Episode: 160 | Qmax: -405.9591
# | Reward: -1654 | Episode: 161 | Qmax: -401.9580
# | Reward: -1050 | Episode: 162 | Qmax: -381.5200
# | Reward: -1639 | Episode: 163 | Qmax: -395.0227
# | Reward: -1171 | Episode: 164 | Qmax: -418.9687
# | Reward: -1318 | Episode: 165 | Qmax: -412.2274
# | Reward: -1446 | Episode: 166 | Qmax: -419.6219
# | Reward: -1319 | Episode: 167 | Qmax: -418.1686
# | Reward: -1177 | Episode: 168 | Qmax: -420.7944
# | Reward: -1144 | Episode: 169 | Qmax: -418.3893
# | Reward: -1485 | Episode: 170 | Qmax: -401.3384
# | Reward: -1157 | Episode: 171 | Qmax: -415.8383
# | Reward: -607 | Episode: 172 | Qmax: -396.9699
# | Reward: -499 | Episode: 173 | Qmax: -388.2608
# | Reward: -841 | Episode: 174 | Qmax: -397.7980
# | Reward: -1299 | Episode: 175 | Qmax: -390.6564
# | Reward: -1671 | Episode: 176 | Qmax: -394.4614
# | Reward: -1524 | Episode: 177 | Qmax: -395.1081
# | Reward: -370 | Episode: 178 | Qmax: -407.2654
# | Reward: -1494 | Episode: 179 | Qmax: -418.4224
# | Reward: -1182 | Episode: 180 | Qmax: -446.3433
# | Reward: -1511 | Episode: 181 | Qmax: -458.4331
# | Reward: -1365 | Episode: 182 | Qmax: -424.9167
# | Reward: -1508 | Episode: 183 | Qmax: -413.3012
# | Reward: -1506 | Episode: 184 | Qmax: -410.2062
# | Reward: -1515 | Episode: 185 | Qmax: -420.3443
# | Reward: -1595 | Episode: 186 | Qmax: -406.7454
# | Reward: -1538 | Episode: 187 | Qmax: -402.7870
# | Reward: -1521 | Episode: 188 | Qmax: -398.9087
# | Reward: -1554 | Episode: 189 | Qmax: -410.2024
# | Reward: -1455 | Episode: 190 | Qmax: -389.5780
# | Reward: -1151 | Episode: 191 | Qmax: -393.9636
# | Reward: -1531 | Episode: 192 | Qmax: -388.7876
# | Reward: -625 | Episode: 193 | Qmax: -384.6790
# | Reward: -737 | Episode: 194 | Qmax: -384.9434
# | Reward: -672 | Episode: 195 | Qmax: -374.2746
# | Reward: -837 | Episode: 196 | Qmax: -368.4391
# | Reward: -948 | Episode: 197 | Qmax: -361.5979
# | Reward: -1589 | Episode: 198 | Qmax: -371.5272
# | Reward: -1035 | Episode: 199 | Qmax: -357.4933
# | Reward: -750 | Episode: 200 | Qmax: -371.8320
# | Reward: -1181 | Episode: 201 | Qmax: -361.1897
# | Reward: -742 | Episode: 202 | Qmax: -366.5810
# | Reward: -1492 | Episode: 203 | Qmax: -343.1696
# | Reward: -852 | Episode: 204 | Qmax: -348.6812
# | Reward: -693 | Episode: 205 | Qmax: -341.6187
# | Reward: -749 | Episode: 206 | Qmax: -332.8035
# | Reward: -1504 | Episode: 207 | Qmax: -324.0061
# | Reward: -1183 | Episode: 208 | Qmax: -341.2926
# | Reward: -867 | Episode: 209 | Qmax: -334.7643
# | Reward: -1281 | Episode: 210 | Qmax: -358.7240
# | Reward: -1545 | Episode: 211 | Qmax: -344.8940
# | Reward: -1509 | Episode: 212 | Qmax: -348.4917
# | Reward: -752 | Episode: 213 | Qmax: -341.1702
# | Reward: -742 | Episode: 214 | Qmax: -344.6848
# | Reward: -973 | Episode: 215 | Qmax: -311.3637
# | Reward: -1193 | Episode: 216 | Qmax: -330.6067
# | Reward: -739 | Episode: 217 | Qmax: -313.9571
# | Reward: -757 | Episode: 218 | Qmax: -307.3018
# | Reward: -1210 | Episode: 219 | Qmax: -318.7478
# | Reward: -743 | Episode: 220 | Qmax: -305.9292
# | Reward: -743 | Episode: 221 | Qmax: -298.1625
# | Reward: -1507 | Episode: 222 | Qmax: -294.1465
# | Reward: -747 | Episode: 223 | Qmax: -289.7226
# | Reward: -694 | Episode: 224 | Qmax: -276.5493
# | Reward: -1360 | Episode: 225 | Qmax: -274.9465
# | Reward: -748 | Episode: 226 | Qmax: -263.5226
# | Reward: -1215 | Episode: 227 | Qmax: -246.5531
# | Reward: -1144 | Episode: 228 | Qmax: -254.2143
# | Reward: -736 | Episode: 229 | Qmax: -247.5660
# | Reward: -749 | Episode: 230 | Qmax: -265.0253
# | Reward: -871 | Episode: 231 | Qmax: -265.9647
# | Reward: -1495 | Episode: 232 | Qmax: -264.4744
# | Reward: -744 | Episode: 233 | Qmax: -263.3376
# | Reward: -735 | Episode: 234 | Qmax: -253.1466
# | Reward: -752 | Episode: 235 | Qmax: -236.1310
# | Reward: -607 | Episode: 236 | Qmax: -242.1532
# | Reward: -619 | Episode: 237 | Qmax: -275.7062
# | Reward: -637 | Episode: 238 | Qmax: -267.5699
# | Reward: -736 | Episode: 239 | Qmax: -266.9611
# | Reward: -735 | Episode: 240 | Qmax: -265.1331
# | Reward: -1512 | Episode: 241 | Qmax: -263.6085
# | Reward: -1532 | Episode: 242 | Qmax: -254.3385
# | Reward: -1442 | Episode: 243 | Qmax: -254.6531
# | Reward: -616 | Episode: 244 | Qmax: -258.3929
# | Reward: -953 | Episode: 245 | Qmax: -250.7581
# | Reward: -1369 | Episode: 246 | Qmax: -242.1554
# | Reward: -624 | Episode: 247 | Qmax: -238.1082
# | Reward: -1380 | Episode: 248 | Qmax: -240.2412
# | Reward: -746 | Episode: 249 | Qmax: -223.2452
# | Reward: -1249 | Episode: 250 | Qmax: -224.3398
# | Reward: -752 | Episode: 251 | Qmax: -223.4926
# | Reward: -1216 | Episode: 252 | Qmax: -218.6516
# | Reward: -1520 | Episode: 253 | Qmax: -203.2519
# | Reward: -616 | Episode: 254 | Qmax: -213.7291
# | Reward: -497 | Episode: 255 | Qmax: -194.3659
# | Reward: -1173 | Episode: 256 | Qmax: -204.7111
# | Reward: -1484 | Episode: 257 | Qmax: -194.7923
# | Reward: -627 | Episode: 258 | Qmax: -182.5070
# | Reward: -1435 | Episode: 259 | Qmax: -183.1827
# | Reward: -610 | Episode: 260 | Qmax: -180.5444
# | Reward: -617 | Episode: 261 | Qmax: -182.4465
# | Reward: -616 | Episode: 262 | Qmax: -168.4650
# | Reward: -1177 | Episode: 263 | Qmax: -165.7736
# | Reward: -497 | Episode: 264 | Qmax: -161.4785
# | Reward: -1298 | Episode: 265 | Qmax: -163.0453
# | Reward: -1185 | Episode: 266 | Qmax: -141.9514
# | Reward: -1041 | Episode: 267 | Qmax: -126.9310
# | Reward: -448 | Episode: 268 | Qmax: -117.5303
# | Reward: -375 | Episode: 269 | Qmax: -123.9298
# | Reward: -1546 | Episode: 270 | Qmax: -110.4460
# | Reward: -496 | Episode: 271 | Qmax: -126.3511
# | Reward: -490 | Episode: 272 | Qmax: -113.3604
# | Reward: -1501 | Episode: 273 | Qmax: -116.0994
# | Reward: -378 | Episode: 274 | Qmax: -119.7206
# | Reward: -783 | Episode: 275 | Qmax: -101.3472
# | Reward: -612 | Episode: 276 | Qmax: -93.0330
# | Reward: -251 | Episode: 277 | Qmax: -79.0339
# | Reward: -138 | Episode: 278 | Qmax: -81.0913
# | Reward: -1048 | Episode: 279 | Qmax: -73.5233
# | Reward: -1383 | Episode: 280 | Qmax: -76.7988
# | Reward: -122 | Episode: 281 | Qmax: -66.1946
# | Reward: -1520 | Episode: 282 | Qmax: -58.4650
# | Reward: -8 | Episode: 283 | Qmax: -65.1045
# | Reward: -1123 | Episode: 284 | Qmax: -63.7704
# | Reward: -127 | Episode: 285 | Qmax: -59.6075
# | Reward: -1522 | Episode: 286 | Qmax: -51.1767
# | Reward: -1498 | Episode: 287 | Qmax: -45.0518
# | Reward: -122 | Episode: 288 | Qmax: -25.2937
# | Reward: -1296 | Episode: 289 | Qmax: -39.2205
# | Reward: -1603 | Episode: 290 | Qmax: -25.6219
# | Reward: -1173 | Episode: 291 | Qmax: -23.8705
# | Reward: -131 | Episode: 292 | Qmax: -14.2194
# | Reward: -126 | Episode: 293 | Qmax: -9.4723
# | Reward: -1231 | Episode: 294 | Qmax: -20.8427
# | Reward: -4 | Episode: 295 | Qmax: -12.4996
# | Reward: -1345 | Episode: 296 | Qmax: -27.2065
# | Reward: -125 | Episode: 297 | Qmax: -20.8815
# | Reward: -122 | Episode: 298 | Qmax: -24.5032
# | Reward: -1526 | Episode: 299 | Qmax: -22.2949
# | Reward: -120 | Episode: 300 | Qmax: -17.3803
# | Reward: -1581 | Episode: 301 | Qmax: -15.9555
# | Reward: -242 | Episode: 302 | Qmax: -10.8459
# | Reward: -372 | Episode: 303 | Qmax: -14.0707
# | Reward: -634 | Episode: 304 | Qmax: -6.1298
# | Reward: -1324 | Episode: 305 | Qmax: -7.3248
# | Reward: -840 | Episode: 306 | Qmax: -3.7067
# | Reward: -1528 | Episode: 307 | Qmax: -6.7701
# | Reward: -123 | Episode: 308 | Qmax: -7.7748
# | Reward: -1156 | Episode: 309 | Qmax: -6.8044
# | Reward: -1102 | Episode: 310 | Qmax: -9.9864
# | Reward: -1333 | Episode: 311 | Qmax: -12.2285
# | Reward: -1011 | Episode: 312 | Qmax: -12.5344
# | Reward: -1175 | Episode: 313 | Qmax: -13.4423
# | Reward: -121 | Episode: 314 | Qmax: -15.7912
# | Reward: -1588 | Episode: 315 | Qmax: -11.2213
# | Reward: -1286 | Episode: 316 | Qmax: -9.4653
# | Reward: -1610 | Episode: 317 | Qmax: -5.7441
# | Reward: -1310 | Episode: 318 | Qmax: -5.8079
# | Reward: -127 | Episode: 319 | Qmax: -3.8782
# | Reward: -941 | Episode: 320 | Qmax: -6.5425
# | Reward: -710 | Episode: 321 | Qmax: -6.7841
# | Reward: -5 | Episode: 322 | Qmax: -4.3876
# | Reward: -938 | Episode: 323 | Qmax: -5.7825
# | Reward: -478 | Episode: 324 | Qmax: -5.0210
# | Reward: -1523 | Episode: 325 | Qmax: -3.7635
# | Reward: -1252 | Episode: 326 | Qmax: -4.1191
# | Reward: -6 | Episode: 327 | Qmax: -4.9658
# | Reward: -124 | Episode: 328 | Qmax: -4.6112
# | Reward: -120 | Episode: 329 | Qmax: -2.5959
# | Reward: -1213 | Episode: 330 | Qmax: -3.5592
# | Reward: -1523 | Episode: 331 | Qmax: -2.7345
# | Reward: -1167 | Episode: 332 | Qmax: -3.4056
# | Reward: -1455 | Episode: 333 | Qmax: -3.4249
# | Reward: -1041 | Episode: 334 | Qmax: -3.8620
# | Reward: -593 | Episode: 335 | Qmax: -2.2679
# | Reward: -248 | Episode: 336 | Qmax: -2.6749
# | Reward: -1196 | Episode: 337 | Qmax: -2.1575
# | Reward: -125 | Episode: 338 | Qmax: -2.1205
# | Reward: -1531 | Episode: 339 | Qmax: -1.5385
# | Reward: -1224 | Episode: 340 | Qmax: -1.7198
# | Reward: -1156 | Episode: 341 | Qmax: -1.7652
# | Reward: -1596 | Episode: 342 | Qmax: -1.8751
# | Reward: -1128 | Episode: 343 | Qmax: -1.4749
# | Reward: -1218 | Episode: 344 | Qmax: -2.3568
# | Reward: -122 | Episode: 345 | Qmax: -1.9570
# | Reward: -250 | Episode: 346 | Qmax: -1.1638
# | Reward: -1203 | Episode: 347 | Qmax: -1.6139
# | Reward: -1502 | Episode: 348 | Qmax: -1.3049
# | Reward: -1221 | Episode: 349 | Qmax: -1.2565
# | Reward: -736 | Episode: 350 | Qmax: -1.2452
# | Reward: -1071 | Episode: 351 | Qmax: -1.3699
# | Reward: -126 | Episode: 352 | Qmax: -1.5436
# | Reward: -1384 | Episode: 353 | Qmax: -1.4137
# | Reward: -245 | Episode: 354 | Qmax: -1.4418
# | Reward: -131 | Episode: 355 | Qmax: -2.0474
# | Reward: -129 | Episode: 356 | Qmax: -1.6812
# | Reward: -1493 | Episode: 357 | Qmax: -0.9113
# | Reward: -1515 | Episode: 358 | Qmax: -1.3801
# | Reward: -1378 | Episode: 359 | Qmax: -1.0139
# | Reward: -1296 | Episode: 360 | Qmax: -1.1228
# | Reward: -123 | Episode: 361 | Qmax: -1.1652
# | Reward: -1238 | Episode: 362 | Qmax: -0.8005
# | Reward: -1362 | Episode: 363 | Qmax: -0.8236
# | Reward: -129 | Episode: 364 | Qmax: -0.8233
# | Reward: -130 | Episode: 365 | Qmax: -0.7574
# | Reward: -1341 | Episode: 366 | Qmax: -0.8233
# | Reward: -1254 | Episode: 367 | Qmax: -0.8402
# | Reward: -6 | Episode: 368 | Qmax: -0.6986
# | Reward: -135 | Episode: 369 | Qmax: -0.8129
# | Reward: -479 | Episode: 370 | Qmax: -2.1907
# | Reward: -126 | Episode: 371 | Qmax: -1.2301
# | Reward: -7 | Episode: 372 | Qmax: -1.5028
# | Reward: -1252 | Episode: 373 | Qmax: -0.9785
# | Reward: -1580 | Episode: 374 | Qmax: -1.0682
# | Reward: -1187 | Episode: 375 | Qmax: -1.1717
# | Reward: -1346 | Episode: 376 | Qmax: -1.1913
# | Reward: -1453 | Episode: 377 | Qmax: -1.1540
# | Reward: -1475 | Episode: 378 | Qmax: -1.0435
# | Reward: -1418 | Episode: 379 | Qmax: -0.8732
# | Reward: -1287 | Episode: 380 | Qmax: -1.0447
# | Reward: -1565 | Episode: 381 | Qmax: -1.0586
# | Reward: -1500 | Episode: 382 | Qmax: -1.1136
# | Reward: -1331 | Episode: 383 | Qmax: -1.3116
# | Reward: -1256 | Episode: 384 | Qmax: -1.3668
# | Reward: -129 | Episode: 385 | Qmax: -1.4346
# | Reward: -372 | Episode: 386 | Qmax: -1.4398
# | Reward: -1502 | Episode: 387 | Qmax: -1.4456
# | Reward: -132 | Episode: 388 | Qmax: -1.4724
# | Reward: -1495 | Episode: 389 | Qmax: -1.4618
# | Reward: -126 | Episode: 390 | Qmax: -1.5160
# | Reward: -244 | Episode: 391 | Qmax: -1.5615
# | Reward: -126 | Episode: 392 | Qmax: -1.4182
# | Reward: -132 | Episode: 393 | Qmax: -1.5098
# | Reward: -1494 | Episode: 394 | Qmax: -1.5877
# | Reward: -257 | Episode: 395 | Qmax: -1.6877
# | Reward: -126 | Episode: 396 | Qmax: -1.6528
# | Reward: -11 | Episode: 397 | Qmax: -1.5836
# | Reward: -124 | Episode: 398 | Qmax: -1.7119
# | Reward: -1327 | Episode: 399 | Qmax: -1.8561
# | Reward: -132 | Episode: 400 | Qmax: -1.9369
# | Reward: -1372 | Episode: 401 | Qmax: -2.2158
# | Reward: -7 | Episode: 402 | Qmax: -2.1956
# | Reward: -1123 | Episode: 403 | Qmax: -2.0994
# | Reward: -136 | Episode: 404 | Qmax: -2.1669
# | Reward: -1063 | Episode: 405 | Qmax: -2.1708
# | Reward: -1523 | Episode: 406 | Qmax: -1.9934
# | Reward: -1201 | Episode: 407 | Qmax: -2.1385
# | Reward: -1040 | Episode: 408 | Qmax: -2.1264
# | Reward: -131 | Episode: 409 | Qmax: -2.0586
# | Reward: -11 | Episode: 410 | Qmax: -2.0139
# | Reward: -11 | Episode: 411 | Qmax: -2.0930
# | Reward: -1091 | Episode: 412 | Qmax: -2.1523
# | Reward: -129 | Episode: 413 | Qmax: -2.0967
# | Reward: -381 | Episode: 414 | Qmax: -2.0695
# | Reward: -125 | Episode: 415 | Qmax: -2.1003
# | Reward: -365 | Episode: 416 | Qmax: -2.0346
# | Reward: -126 | Episode: 417 | Qmax: -2.0059
# | Reward: -257 | Episode: 418 | Qmax: -2.2363
# | Reward: -444 | Episode: 419 | Qmax: -2.0809
# | Reward: -248 | Episode: 420 | Qmax: -2.1482
# | Reward: -122 | Episode: 421 | Qmax: -2.1720
# | Reward: -387 | Episode: 422 | Qmax: -2.1466
# | Reward: -258 | Episode: 423 | Qmax: -2.0661
# | Reward: -311 | Episode: 424 | Qmax: -2.0542
# | Reward: -503 | Episode: 425 | Qmax: -2.0669
# | Reward: -365 | Episode: 426 | Qmax: -1.9969
# | Reward: -127 | Episode: 427 | Qmax: -1.8143
# | Reward: -389 | Episode: 428 | Qmax: -1.7997
# | Reward: -623 | Episode: 429 | Qmax: -1.7431
# | Reward: -465 | Episode: 430 | Qmax: -1.8224
# | Reward: -376 | Episode: 431 | Qmax: -1.8306
# | Reward: -393 | Episode: 432 | Qmax: -1.7031
# | Reward: -9 | Episode: 433 | Qmax: -1.6854
# | Reward: -262 | Episode: 434 | Qmax: -1.7628
# | Reward: -253 | Episode: 435 | Qmax: -1.6498
# | Reward: -259 | Episode: 436 | Qmax: -1.4638
# | Reward: -237 | Episode: 437 | Qmax: -1.4491
# | Reward: -9 | Episode: 438 | Qmax: -1.4433
# | Reward: -131 | Episode: 439 | Qmax: -1.4582
# | Reward: -9 | Episode: 440 | Qmax: -1.6127
# | Reward: -8 | Episode: 441 | Qmax: -1.6696
# | Reward: -125 | Episode: 442 | Qmax: -1.5347
# | Reward: -259 | Episode: 443 | Qmax: -1.4414
# | Reward: -130 | Episode: 444 | Qmax: -1.5010
# | Reward: -261 | Episode: 445 | Qmax: -1.5195
# | Reward: -131 | Episode: 446 | Qmax: -1.5601
# | Reward: -264 | Episode: 447 | Qmax: -1.5073
# | Reward: -360 | Episode: 448 | Qmax: -1.4760
# | Reward: -126 | Episode: 449 | Qmax: -1.3766
# | Reward: -241 | Episode: 450 | Qmax: -1.3547
# | Reward: -137 | Episode: 451 | Qmax: -1.3778
# | Reward: -249 | Episode: 452 | Qmax: -1.2857
# | Reward: -248 | Episode: 453 | Qmax: -1.1856
# | Reward: -262 | Episode: 454 | Qmax: -1.2351
# | Reward: -134 | Episode: 455 | Qmax: -1.2702
# | Reward: -11 | Episode: 456 | Qmax: -1.2713
# | Reward: -134 | Episode: 457 | Qmax: -1.2370
# | Reward: -134 | Episode: 458 | Qmax: -1.1954
# | Reward: -141 | Episode: 459 | Qmax: -1.1921
# | Reward: -257 | Episode: 460 | Qmax: -1.2152
# | Reward: -131 | Episode: 461 | Qmax: -1.1543
# | Reward: -371 | Episode: 462 | Qmax: -1.2355
# | Reward: -244 | Episode: 463 | Qmax: -1.2311
# | Reward: -122 | Episode: 464 | Qmax: -1.2333
# | Reward: -266 | Episode: 465 | Qmax: -1.2448
# | Reward: -388 | Episode: 466 | Qmax: -1.3204
# | Reward: -8 | Episode: 467 | Qmax: -1.3569
# | Reward: -132 | Episode: 468 | Qmax: -1.3854
# | Reward: -257 | Episode: 469 | Qmax: -1.3834
# | Reward: -136 | Episode: 470 | Qmax: -1.3450
# | Reward: -137 | Episode: 471 | Qmax: -1.4527
# | Reward: -7 | Episode: 472 | Qmax: -1.5633
# | Reward: -421 | Episode: 473 | Qmax: -1.5694
# | Reward: -245 | Episode: 474 | Qmax: -1.6082
# | Reward: -10 | Episode: 475 | Qmax: -1.5415
# | Reward: -478 | Episode: 476 | Qmax: -1.5422
# | Reward: -243 | Episode: 477 | Qmax: -1.5084
# | Reward: -133 | Episode: 478 | Qmax: -1.4642
# | Reward: -10 | Episode: 479 | Qmax: -1.4607
# | Reward: -129 | Episode: 480 | Qmax: -1.3720
# | Reward: -251 | Episode: 481 | Qmax: -1.5399
# | Reward: -241 | Episode: 482 | Qmax: -1.5746
# | Reward: -123 | Episode: 483 | Qmax: -1.4921
# | Reward: -374 | Episode: 484 | Qmax: -1.6346
# | Reward: -126 | Episode: 485 | Qmax: -1.6456
# | Reward: -127 | Episode: 486 | Qmax: -1.7279
# | Reward: -125 | Episode: 487 | Qmax: -1.8059
# | Reward: -123 | Episode: 488 | Qmax: -1.7984
# | Reward: -5 | Episode: 489 | Qmax: -1.7752
# | Reward: -120 | Episode: 490 | Qmax: -1.7762
# | Reward: -122 | Episode: 491 | Qmax: -1.8058
# | Reward: -259 | Episode: 492 | Qmax: -1.9602
# | Reward: -255 | Episode: 493 | Qmax: -1.8780
# | Reward: -379 | Episode: 494 | Qmax: -1.8637
# | Reward: -7 | Episode: 495 | Qmax: -1.8856
# | Reward: -255 | Episode: 496 | Qmax: -2.1284
# | Reward: -249 | Episode: 497 | Qmax: -2.5088
# | Reward: -256 | Episode: 498 | Qmax: -2.7748
# | Reward: -8 | Episode: 499 | Qmax: -2.7857
# | Reward: -9 | Episode: 500 | Qmax: -2.7607
# | Reward: -131 | Episode: 501 | Qmax: -2.7572
# | Reward: -135 | Episode: 502 | Qmax: -2.8398
# | Reward: -123 | Episode: 503 | Qmax: -2.8295
# | Reward: -126 | Episode: 504 | Qmax: -2.6960
# | Reward: -126 | Episode: 505 | Qmax: -2.8530
# | Reward: -126 | Episode: 506 | Qmax: -2.9998
# | Reward: -133 | Episode: 507 | Qmax: -2.5604
# | Reward: -127 | Episode: 508 | Qmax: -2.7845
# | Reward: -249 | Episode: 509 | Qmax: -2.9808
# | Reward: -7 | Episode: 510 | Qmax: -2.8817
# | Reward: -246 | Episode: 511 | Qmax: -2.5668
# | Reward: -476 | Episode: 512 | Qmax: -2.9790
# | Reward: -369 | Episode: 513 | Qmax: -3.0465
# | Reward: -122 | Episode: 514 | Qmax: -3.1840
# | Reward: -6 | Episode: 515 | Qmax: -3.4702
# | Reward: -246 | Episode: 516 | Qmax: -3.1694
# | Reward: -469 | Episode: 517 | Qmax: -3.9629
# | Reward: -333 | Episode: 518 | Qmax: -3.6219
# | Reward: -255 | Episode: 519 | Qmax: -3.4541
# | Reward: -243 | Episode: 520 | Qmax: -3.4666
# | Reward: -122 | Episode: 521 | Qmax: -3.1546
# | Reward: -126 | Episode: 522 | Qmax: -2.4158
# | Reward: -235 | Episode: 523 | Qmax: -2.7212
# | Reward: -123 | Episode: 524 | Qmax: -2.8179
# | Reward: -117 | Episode: 525 | Qmax: -2.8401
# | Reward: -127 | Episode: 526 | Qmax: -2.9835
# | Reward: -249 | Episode: 527 | Qmax: -3.0282
# | Reward: -280 | Episode: 528 | Qmax: -2.6541
# | Reward: -124 | Episode: 529 | Qmax: -2.7609
# | Reward: -250 | Episode: 530 | Qmax: -2.8332
# | Reward: -232 | Episode: 531 | Qmax: -2.9229
# | Reward: -370 | Episode: 532 | Qmax: -2.5291
# | Reward: -276 | Episode: 533 | Qmax: -2.2078
# | Reward: -260 | Episode: 534 | Qmax: -2.1292
# | Reward: -126 | Episode: 535 | Qmax: -1.8897
# | Reward: -256 | Episode: 536 | Qmax: -1.6610
# | Reward: -130 | Episode: 537 | Qmax: -1.5657
# | Reward: -234 | Episode: 538 | Qmax: -1.4096
# | Reward: -367 | Episode: 539 | Qmax: -1.2654
# | Reward: 0 | Episode: 540 | Qmax: -1.1773
# | Reward: -128 | Episode: 541 | Qmax: -1.0299
# | Reward: -250 | Episode: 542 | Qmax: -0.9831
# | Reward: -236 | Episode: 543 | Qmax: -0.8833
# | Reward: -381 | Episode: 544 | Qmax: -0.7512
# | Reward: -124 | Episode: 545 | Qmax: -0.6791
# | Reward: -125 | Episode: 546 | Qmax: -0.6850
# | Reward: -356 | Episode: 547 | Qmax: -0.6129
# | Reward: -126 | Episode: 548 | Qmax: -0.5363
# | Reward: -1 | Episode: 549 | Qmax: -0.4115
# | Reward: -233 | Episode: 550 | Qmax: -0.2881
# | Reward: -232 | Episode: 551 | Qmax: -0.2873
# | Reward: -379 | Episode: 552 | Qmax: -0.2318
# | Reward: -1 | Episode: 553 | Qmax: -0.2338
# | Reward: -128 | Episode: 554 | Qmax: -0.2322
# | Reward: -127 | Episode: 555 | Qmax: -0.2347
# | Reward: -245 | Episode: 556 | Qmax: -0.2288
# | Reward: -138 | Episode: 557 | Qmax: -0.2290
# | Reward: -239 | Episode: 558 | Qmax: -0.2276
# | Reward: -331 | Episode: 559 | Qmax: -0.2255
# | Reward: -126 | Episode: 560 | Qmax: -0.2248
# | Reward: -126 | Episode: 561 | Qmax: -0.2260
# | Reward: -231 | Episode: 562 | Qmax: -0.2233
# | Reward: -123 | Episode: 563 | Qmax: -0.2239
# | Reward: -1 | Episode: 564 | Qmax: -0.2254
# | Reward: -338 | Episode: 565 | Qmax: -0.2270
# | Reward: -115 | Episode: 566 | Qmax: -0.2175
# | Reward: -130 | Episode: 567 | Qmax: -0.2153
# | Reward: -361 | Episode: 568 | Qmax: -0.2201
# | Reward: -1 | Episode: 569 | Qmax: -0.2130
# | Reward: -122 | Episode: 570 | Qmax: -0.2111
# | Reward: -123 | Episode: 571 | Qmax: -0.2110
# | Reward: -246 | Episode: 572 | Qmax: -0.2112
# | Reward: -121 | Episode: 573 | Qmax: -0.2105
# | Reward: -124 | Episode: 574 | Qmax: -0.2129
# | Reward: -130 | Episode: 575 | Qmax: -0.2096
# | Reward: -246 | Episode: 576 | Qmax: -0.2050
# | Reward: -389 | Episode: 577 | Qmax: -0.2036
# | Reward: -235 | Episode: 578 | Qmax: -0.2062
# | Reward: -125 | Episode: 579 | Qmax: -0.2057
# | Reward: -241 | Episode: 580 | Qmax: -0.2159
# | Reward: -124 | Episode: 581 | Qmax: -0.2058
# | Reward: 0 | Episode: 582 | Qmax: -0.2014
# | Reward: -121 | Episode: 583 | Qmax: -0.1997
# | Reward: -126 | Episode: 584 | Qmax: -0.1979
# | Reward: -130 | Episode: 585 | Qmax: -0.1961
# | Reward: -118 | Episode: 586 | Qmax: -0.1944
# | Reward: -123 | Episode: 587 | Qmax: -0.1912
# | Reward: -486 | Episode: 588 | Qmax: -0.1890
# | Reward: -234 | Episode: 589 | Qmax: -0.1880
# | Reward: -253 | Episode: 590 | Qmax: -0.1897
# | Reward: -372 | Episode: 591 | Qmax: -0.1870
# | Reward: -374 | Episode: 592 | Qmax: -0.1865
# | Reward: -368 | Episode: 593 | Qmax: -0.1854
# | Reward: -120 | Episode: 594 | Qmax: -0.1839
# | Reward: -125 | Episode: 595 | Qmax: -0.1844
# | Reward: -246 | Episode: 596 | Qmax: -0.1834
# | Reward: -118 | Episode: 597 | Qmax: -0.1793
# | Reward: -129 | Episode: 598 | Qmax: -0.1785
# | Reward: -379 | Episode: 599 | Qmax: -0.1790
# | Reward: -247 | Episode: 600 | Qmax: -0.1774
# | Reward: -122 | Episode: 601 | Qmax: -0.1732
# | Reward: -119 | Episode: 602 | Qmax: -0.1729
# | Reward: -124 | Episode: 603 | Qmax: -0.1743
# | Reward: 0 | Episode: 604 | Qmax: -0.1761
# | Reward: 0 | Episode: 605 | Qmax: -0.1750
# | Reward: -118 | Episode: 606 | Qmax: -0.1709
# | Reward: -484 | Episode: 607 | Qmax: -0.1700
# | Reward: -285 | Episode: 608 | Qmax: -0.1694
# | Reward: -123 | Episode: 609 | Qmax: -0.1688
# | Reward: -1 | Episode: 610 | Qmax: -0.1688
# | Reward: -233 | Episode: 611 | Qmax: -0.1694
# | Reward: -229 | Episode: 612 | Qmax: -0.1649
# | Reward: -1 | Episode: 613 | Qmax: -0.1605
# | Reward: -2 | Episode: 614 | Qmax: -0.1590
# | Reward: -273 | Episode: 615 | Qmax: -0.1591
# | Reward: -3 | Episode: 616 | Qmax: -0.1543
# | Reward: -122 | Episode: 617 | Qmax: -0.1506
# | Reward: -239 | Episode: 618 | Qmax: -0.1508
# | Reward: -123 | Episode: 619 | Qmax: -0.1509
# | Reward: -120 | Episode: 620 | Qmax: -0.1483
# | Reward: -122 | Episode: 621 | Qmax: -0.1494
# | Reward: -124 | Episode: 622 | Qmax: -0.1510
# | Reward: -242 | Episode: 623 | Qmax: -0.1508
# | Reward: -1 | Episode: 624 | Qmax: -0.1511
# | Reward: -269 | Episode: 625 | Qmax: -0.1527
# | Reward: -370 | Episode: 626 | Qmax: -0.1521
# | Reward: -124 | Episode: 627 | Qmax: -0.1501
# | Reward: -2 | Episode: 628 | Qmax: -0.1481
# | Reward: -272 | Episode: 629 | Qmax: -0.1489
# | Reward: -234 | Episode: 630 | Qmax: -0.1474
# | Reward: -123 | Episode: 631 | Qmax: -0.1482
# | Reward: -131 | Episode: 632 | Qmax: -0.1437
# | Reward: -127 | Episode: 633 | Qmax: -0.1412
# | Reward: -246 | Episode: 634 | Qmax: -0.1398
# | Reward: -244 | Episode: 635 | Qmax: -0.1402
# | Reward: 0 | Episode: 636 | Qmax: -0.1392
# | Reward: -252 | Episode: 637 | Qmax: -0.1376
# | Reward: -2 | Episode: 638 | Qmax: -0.1358
# | Reward: -257 | Episode: 639 | Qmax: -0.1349
# | Reward: -248 | Episode: 640 | Qmax: -0.1346
# | Reward: -124 | Episode: 641 | Qmax: -0.1325
# | Reward: -369 | Episode: 642 | Qmax: -0.1362
# | Reward: -129 | Episode: 643 | Qmax: -0.1318
# | Reward: -244 | Episode: 644 | Qmax: -0.1298
# | Reward: -127 | Episode: 645 | Qmax: -0.1324
# | Reward: -251 | Episode: 646 | Qmax: -0.1323
# | Reward: -124 | Episode: 647 | Qmax: -0.1321
# | Reward: -124 | Episode: 648 | Qmax: -0.1324
# | Reward: -1 | Episode: 649 | Qmax: -0.1351
# | Reward: -1 | Episode: 650 | Qmax: -0.1330
# | Reward: -243 | Episode: 651 | Qmax: -0.1356
# | Reward: 0 | Episode: 652 | Qmax: -0.1343
# | Reward: -317 | Episode: 653 | Qmax: -0.1317
# | Reward: -231 | Episode: 654 | Qmax: -0.1298
# | Reward: -235 | Episode: 655 | Qmax: -0.1294
# | Reward: -123 | Episode: 656 | Qmax: -0.1331
# | Reward: -231 | Episode: 657 | Qmax: -0.1344
# | Reward: 0 | Episode: 658 | Qmax: -0.1336
# | Reward: -347 | Episode: 659 | Qmax: -0.1306
# | Reward: -125 | Episode: 660 | Qmax: -0.1326
# | Reward: -117 | Episode: 661 | Qmax: -0.1326
# | Reward: -133 | Episode: 662 | Qmax: -0.1313
# | Reward: -509 | Episode: 663 | Qmax: -0.1301
# | Reward: -6 | Episode: 664 | Qmax: -0.1278
# | Reward: -377 | Episode: 665 | Qmax: -0.1284
# | Reward: -124 | Episode: 666 | Qmax: -0.1289
# | Reward: -405 | Episode: 667 | Qmax: -0.1287
# | Reward: -380 | Episode: 668 | Qmax: -0.1279
# | Reward: -335 | Episode: 669 | Qmax: -0.1284
# | Reward: -123 | Episode: 670 | Qmax: -0.1274
# | Reward: -128 | Episode: 671 | Qmax: -0.1266
# | Reward: -251 | Episode: 672 | Qmax: -0.1261
# | Reward: -129 | Episode: 673 | Qmax: -0.1297
# | Reward: -125 | Episode: 674 | Qmax: -0.1315
# | Reward: -123 | Episode: 675 | Qmax: -0.1275
# | Reward: -239 | Episode: 676 | Qmax: -0.1238
# | Reward: -118 | Episode: 677 | Qmax: -0.1241
# | Reward: -124 | Episode: 678 | Qmax: -0.1232
# | Reward: -128 | Episode: 679 | Qmax: -0.1224
# | Reward: -3 | Episode: 680 | Qmax: -0.1185
# | Reward: -352 | Episode: 681 | Qmax: -0.1171
# | Reward: -6 | Episode: 682 | Qmax: -0.1158
# | Reward: -131 | Episode: 683 | Qmax: -0.1136
# | Reward: -377 | Episode: 684 | Qmax: -0.1138
# | Reward: -124 | Episode: 685 | Qmax: -0.1158
# | Reward: -118 | Episode: 686 | Qmax: -0.1173
# | Reward: -124 | Episode: 687 | Qmax: -0.1165
# | Reward: -2 | Episode: 688 | Qmax: -0.1148
# | Reward: -130 | Episode: 689 | Qmax: -0.1168
# | Reward: -126 | Episode: 690 | Qmax: -0.1161
# | Reward: -245 | Episode: 691 | Qmax: -0.1134
# | Reward: -121 | Episode: 692 | Qmax: -0.1164
# | Reward: -238 | Episode: 693 | Qmax: -0.1168
# | Reward: -235 | Episode: 694 | Qmax: -0.1172
# | Reward: -123 | Episode: 695 | Qmax: -0.1160
# | Reward: -4 | Episode: 696 | Qmax: -0.1170
# | Reward: -374 | Episode: 697 | Qmax: -0.1164
# | Reward: -250 | Episode: 698 | Qmax: -0.1148
# | Reward: -126 | Episode: 699 | Qmax: -0.1151
# | Reward: -250 | Episode: 700 | Qmax: -0.1135
# | Reward: -121 | Episode: 701 | Qmax: -0.1117
# | Reward: -360 | Episode: 702 | Qmax: -0.1127
# | Reward: -127 | Episode: 703 | Qmax: -0.1109
# | Reward: -251 | Episode: 704 | Qmax: -0.1131
# | Reward: -365 | Episode: 705 | Qmax: -0.1148
# | Reward: -118 | Episode: 706 | Qmax: -0.1161
# | Reward: -129 | Episode: 707 | Qmax: -0.1190
# | Reward: -125 | Episode: 708 | Qmax: -0.1177
# | Reward: -121 | Episode: 709 | Qmax: -0.1193
# | Reward: -231 | Episode: 710 | Qmax: -0.1152
# | Reward: -125 | Episode: 711 | Qmax: -0.1156
# | Reward: -319 | Episode: 712 | Qmax: -0.1168
# | Reward: -124 | Episode: 713 | Qmax: -0.1170
# | Reward: -127 | Episode: 714 | Qmax: -0.1173
# | Reward: -243 | Episode: 715 | Qmax: -0.1186
# | Reward: -257 | Episode: 716 | Qmax: -0.1189
# | Reward: -239 | Episode: 717 | Qmax: -0.1190
# | Reward: 0 | Episode: 718 | Qmax: -0.1242
# | Reward: -128 | Episode: 719 | Qmax: -0.1242
# | Reward: -376 | Episode: 720 | Qmax: -0.1253
# | Reward: -238 | Episode: 721 | Qmax: -0.1267
# | Reward: 0 | Episode: 722 | Qmax: -0.1263
# | Reward: -121 | Episode: 723 | Qmax: -0.1368
# | Reward: -126 | Episode: 724 | Qmax: -0.1172
# | Reward: -120 | Episode: 725 | Qmax: -0.1225
# | Reward: -125 | Episode: 726 | Qmax: -0.1190
# | Reward: -125 | Episode: 727 | Qmax: -0.1132
# | Reward: -249 | Episode: 728 | Qmax: -0.1119
# | Reward: -121 | Episode: 729 | Qmax: -0.1140
# | Reward: -124 | Episode: 730 | Qmax: -0.1058
# | Reward: -132 | Episode: 731 | Qmax: -0.1089
# | Reward: -248 | Episode: 732 | Qmax: -0.1179
# | Reward: -256 | Episode: 733 | Qmax: -0.1170
# | Reward: -122 | Episode: 734 | Qmax: -0.1176
# | Reward: -124 | Episode: 735 | Qmax: -0.1179
# | Reward: -119 | Episode: 736 | Qmax: -0.1205
# | Reward: -128 | Episode: 737 | Qmax: -0.1201
# | Reward: -119 | Episode: 738 | Qmax: -0.1199
# | Reward: -293 | Episode: 739 | Qmax: -0.1187
# | Reward: -361 | Episode: 740 | Qmax: -0.1233
# | Reward: -124 | Episode: 741 | Qmax: -0.1242
# | Reward: -122 | Episode: 742 | Qmax: -0.1231
# | Reward: -247 | Episode: 743 | Qmax: -0.1258
# | Reward: 0 | Episode: 744 | Qmax: -0.1287
# | Reward: -240 | Episode: 745 | Qmax: -0.1292
# | Reward: -124 | Episode: 746 | Qmax: -0.1293
# | Reward: -117 | Episode: 747 | Qmax: -0.1303
# | Reward: -251 | Episode: 748 | Qmax: -0.1334
# | Reward: 0 | Episode: 749 | Qmax: -0.1305
# | Reward: -238 | Episode: 750 | Qmax: -0.1308
# | Reward: -3 | Episode: 751 | Qmax: -0.1296
# | Reward: -127 | Episode: 752 | Qmax: -0.1298
# | Reward: -124 | Episode: 753 | Qmax: -0.1281
# | Reward: -257 | Episode: 754 | Qmax: -0.1293
# | Reward: -230 | Episode: 755 | Qmax: -0.1294
# | Reward: -346 | Episode: 756 | Qmax: -0.1262
# | Reward: 0 | Episode: 757 | Qmax: -0.1248
# | Reward: -239 | Episode: 758 | Qmax: -0.1281
# | Reward: -120 | Episode: 759 | Qmax: -0.1301
# | Reward: -268 | Episode: 760 | Qmax: -0.1288
# | Reward: -125 | Episode: 761 | Qmax: -0.1248
# | Reward: -114 | Episode: 762 | Qmax: -0.1258
# | Reward: -119 | Episode: 763 | Qmax: -0.1270
# | Reward: -117 | Episode: 764 | Qmax: -0.1295
# | Reward: -127 | Episode: 765 | Qmax: -0.1298
# | Reward: -377 | Episode: 766 | Qmax: -0.1273
# | Reward: -388 | Episode: 767 | Qmax: -0.1281
# | Reward: 0 | Episode: 768 | Qmax: -0.1272
# | Reward: -124 | Episode: 769 | Qmax: -0.1332
# | Reward: -117 | Episode: 770 | Qmax: -0.1285
# | Reward: -374 | Episode: 771 | Qmax: -0.1284
# | Reward: -117 | Episode: 772 | Qmax: -0.1282
# | Reward: -125 | Episode: 773 | Qmax: -0.1279
# | Reward: -254 | Episode: 774 | Qmax: -0.1256
# | Reward: -245 | Episode: 775 | Qmax: -0.1236
# | Reward: -123 | Episode: 776 | Qmax: -0.1201
# | Reward: -236 | Episode: 777 | Qmax: -0.1205
# | Reward: -121 | Episode: 778 | Qmax: -0.1169
# | Reward: -339 | Episode: 779 | Qmax: -0.1137
# | Reward: -1 | Episode: 780 | Qmax: -0.1116
# | Reward: -125 | Episode: 781 | Qmax: -0.1118
# | Reward: -118 | Episode: 782 | Qmax: -0.1128
# | Reward: -127 | Episode: 783 | Qmax: -0.1126
# | Reward: -229 | Episode: 784 | Qmax: -0.1120
# | Reward: -124 | Episode: 785 | Qmax: -0.1108
# | Reward: -235 | Episode: 786 | Qmax: -0.1108
# | Reward: -347 | Episode: 787 | Qmax: -0.1111
# | Reward: -120 | Episode: 788 | Qmax: -0.1082
# | Reward: -114 | Episode: 789 | Qmax: -0.1103
# | Reward: -123 | Episode: 790 | Qmax: -0.1118
# | Reward: -118 | Episode: 791 | Qmax: -0.1096
# | Reward: -379 | Episode: 792 | Qmax: -0.1118
# | Reward: -2 | Episode: 793 | Qmax: -0.1144
# | Reward: -123 | Episode: 794 | Qmax: -0.1101
# | Reward: -257 | Episode: 795 | Qmax: -0.1092
# | Reward: -284 | Episode: 796 | Qmax: -0.1113
# | Reward: -251 | Episode: 797 | Qmax: -0.1081
# | Reward: -119 | Episode: 798 | Qmax: -0.1108
# | Reward: -123 | Episode: 799 | Qmax: -0.1168
# | Reward: -241 | Episode: 800 | Qmax: -0.1171
# | Reward: -122 | Episode: 801 | Qmax: -0.1180
# | Reward: -125 | Episode: 802 | Qmax: -0.1197
# | Reward: -241 | Episode: 803 | Qmax: -0.1185
# | Reward: -246 | Episode: 804 | Qmax: -0.1175
# | Reward: -129 | Episode: 805 | Qmax: -0.1155
# | Reward: -121 | Episode: 806 | Qmax: -0.1149
# | Reward: -244 | Episode: 807 | Qmax: -0.1141
# | Reward: -118 | Episode: 808 | Qmax: -0.1123
# | Reward: 0 | Episode: 809 | Qmax: -0.1118
# | Reward: -123 | Episode: 810 | Qmax: -0.1081
# | Reward: -120 | Episode: 811 | Qmax: -0.1063
# | Reward: -114 | Episode: 812 | Qmax: -0.1007
# | Reward: -118 | Episode: 813 | Qmax: -0.1052
# | Reward: 0 | Episode: 814 | Qmax: -0.1087
# | Reward: -248 | Episode: 815 | Qmax: -0.1085
# | Reward: -246 | Episode: 816 | Qmax: -0.1094
# | Reward: -121 | Episode: 817 | Qmax: -0.1048
# | Reward: -632 | Episode: 818 | Qmax: -0.1061
# | Reward: -116 | Episode: 819 | Qmax: -0.1071
# | Reward: -488 | Episode: 820 | Qmax: -0.1017
# | Reward: -118 | Episode: 821 | Qmax: -0.1012
# | Reward: -121 | Episode: 822 | Qmax: -0.1019
# | Reward: -127 | Episode: 823 | Qmax: -0.1023
# | Reward: -124 | Episode: 824 | Qmax: -0.1017
# | Reward: -254 | Episode: 825 | Qmax: -0.1002
# | Reward: -121 | Episode: 826 | Qmax: -0.1004
# | Reward: -234 | Episode: 827 | Qmax: -0.0979
# | Reward: -242 | Episode: 828 | Qmax: -0.0989
# | Reward: -350 | Episode: 829 | Qmax: -0.1002
# | Reward: -253 | Episode: 830 | Qmax: -0.0993
# | Reward: -127 | Episode: 831 | Qmax: -0.0944
# | Reward: -2 | Episode: 832 | Qmax: -0.0964
# | Reward: -241 | Episode: 833 | Qmax: -0.0942
# | Reward: -123 | Episode: 834 | Qmax: -0.0923
# | Reward: -127 | Episode: 835 | Qmax: -0.0938
# | Reward: -118 | Episode: 836 | Qmax: -0.0929
# | Reward: -128 | Episode: 837 | Qmax: -0.0910
# | Reward: -359 | Episode: 838 | Qmax: -0.0897
# | Reward: -120 | Episode: 839 | Qmax: -0.0865
# | Reward: -237 | Episode: 840 | Qmax: -0.0815
# | Reward: -120 | Episode: 841 | Qmax: -0.0837
# | Reward: -281 | Episode: 842 | Qmax: -0.0842
# | Reward: -238 | Episode: 843 | Qmax: -0.0847
# | Reward: -233 | Episode: 844 | Qmax: -0.0869
# | Reward: -1 | Episode: 845 | Qmax: -0.0893
# | Reward: -2 | Episode: 846 | Qmax: -0.0931
# | Reward: -2 | Episode: 847 | Qmax: -0.0895
# | Reward: -122 | Episode: 848 | Qmax: -0.0891
# | Reward: -242 | Episode: 849 | Qmax: -0.0890
# | Reward: -125 | Episode: 850 | Qmax: -0.0912
# | Reward: -120 | Episode: 851 | Qmax: -0.0932
# | Reward: -121 | Episode: 852 | Qmax: -0.0937
# | Reward: -123 | Episode: 853 | Qmax: -0.0877
# | Reward: -127 | Episode: 854 | Qmax: -0.0875
# | Reward: 0 | Episode: 855 | Qmax: -0.0855
# | Reward: -1 | Episode: 856 | Qmax: -0.0807
# | Reward: -366 | Episode: 857 | Qmax: -0.0802
# | Reward: -253 | Episode: 858 | Qmax: -0.0786
# | Reward: 0 | Episode: 859 | Qmax: -0.0784
# | Reward: -244 | Episode: 860 | Qmax: -0.0808
# | Reward: -486 | Episode: 861 | Qmax: -0.0758
# | Reward: -496 | Episode: 862 | Qmax: -0.0781
# | Reward: -245 | Episode: 863 | Qmax: -0.0757
# | Reward: -127 | Episode: 864 | Qmax: -0.0773
# | Reward: -122 | Episode: 865 | Qmax: -0.0797
# | Reward: -128 | Episode: 866 | Qmax: -0.0806
# | Reward: -114 | Episode: 867 | Qmax: -0.0779
# | Reward: -122 | Episode: 868 | Qmax: -0.0833
# | Reward: -256 | Episode: 869 | Qmax: -0.0815
# | Reward: -245 | Episode: 870 | Qmax: -0.0788
# | Reward: -118 | Episode: 871 | Qmax: -0.0770
# | Reward: -244 | Episode: 872 | Qmax: -0.0758
# | Reward: -120 | Episode: 873 | Qmax: -0.0719
# | Reward: -122 | Episode: 874 | Qmax: -0.0753
# | Reward: -3 | Episode: 875 | Qmax: -0.0754
# | Reward: -126 | Episode: 876 | Qmax: -0.0757
# | Reward: -124 | Episode: 877 | Qmax: -0.0738
# | Reward: -115 | Episode: 878 | Qmax: -0.0746
# | Reward: 0 | Episode: 879 | Qmax: -0.0712
# | Reward: -373 | Episode: 880 | Qmax: -0.0690
# | Reward: -122 | Episode: 881 | Qmax: -0.0635
# | Reward: -364 | Episode: 882 | Qmax: -0.0688
# | Reward: -115 | Episode: 883 | Qmax: -0.0697
# | Reward: -238 | Episode: 884 | Qmax: -0.0706
# | Reward: -235 | Episode: 885 | Qmax: -0.0645
# | Reward: -230 | Episode: 886 | Qmax: -0.0678
# | Reward: -239 | Episode: 887 | Qmax: -0.0691
# | Reward: -113 | Episode: 888 | Qmax: -0.0549
# | Reward: -117 | Episode: 889 | Qmax: -0.0654
# | Reward: -245 | Episode: 890 | Qmax: -0.0645
# | Reward: -362 | Episode: 891 | Qmax: -0.0585
# | Reward: -458 | Episode: 892 | Qmax: -0.0628
# | Reward: 0 | Episode: 893 | Qmax: -0.0581
# | Reward: -375 | Episode: 894 | Qmax: -0.0576
# | Reward: -117 | Episode: 895 | Qmax: -0.0480
# | Reward: -1 | Episode: 896 | Qmax: -0.0616
# | Reward: -126 | Episode: 897 | Qmax: -0.0584
# | Reward: -376 | Episode: 898 | Qmax: -0.0592
# | Reward: -126 | Episode: 899 | Qmax: -0.0611
# | Reward: -126 | Episode: 900 | Qmax: -0.0626
# | Reward: -370 | Episode: 901 | Qmax: -0.0652
# | Reward: -382 | Episode: 902 | Qmax: -0.0672
# | Reward: -372 | Episode: 903 | Qmax: -0.0613
# | Reward: -245 | Episode: 904 | Qmax: -0.0601
# | Reward: 0 | Episode: 905 | Qmax: -0.0670
# | Reward: -123 | Episode: 906 | Qmax: -0.0558
# | Reward: -2 | Episode: 907 | Qmax: -0.0635
# | Reward: -121 | Episode: 908 | Qmax: -0.0684
# | Reward: -356 | Episode: 909 | Qmax: -0.0655
# | Reward: -613 | Episode: 910 | Qmax: -0.0636
# | Reward: -365 | Episode: 911 | Qmax: -0.0635
# | Reward: -127 | Episode: 912 | Qmax: -0.0589
# | Reward: -325 | Episode: 913 | Qmax: -0.0591
# | Reward: -115 | Episode: 914 | Qmax: -0.0558
# | Reward: -1 | Episode: 915 | Qmax: -0.0553
# | Reward: -127 | Episode: 916 | Qmax: -0.0555
# | Reward: -119 | Episode: 917 | Qmax: -0.0504
# | Reward: -250 | Episode: 918 | Qmax: -0.0547
# | Reward: -127 | Episode: 919 | Qmax: -0.0475
# | Reward: 0 | Episode: 920 | Qmax: -0.0417
# | Reward: -118 | Episode: 921 | Qmax: -0.0390
# | Reward: -246 | Episode: 922 | Qmax: -0.0320
# | Reward: 0 | Episode: 923 | Qmax: -0.0321
# | Reward: 0 | Episode: 924 | Qmax: -0.0399
# | Reward: -227 | Episode: 925 | Qmax: -0.0257
# | Reward: -123 | Episode: 926 | Qmax: -0.0445
# | Reward: -254 | Episode: 927 | Qmax: -0.0408
# | Reward: -116 | Episode: 928 | Qmax: -0.0408
# | Reward: -115 | Episode: 929 | Qmax: -0.0443
# | Reward: -243 | Episode: 930 | Qmax: -0.0471
# | Reward: -125 | Episode: 931 | Qmax: -0.0434
# | Reward: -244 | Episode: 932 | Qmax: -0.0544
# | Reward: -745 | Episode: 933 | Qmax: -0.0572
# | Reward: -500 | Episode: 934 | Qmax: -0.0532
# | Reward: -279 | Episode: 935 | Qmax: -0.0525
# | Reward: -3 | Episode: 936 | Qmax: -0.0572
# | Reward: -125 | Episode: 937 | Qmax: -0.0544
# | Reward: -253 | Episode: 938 | Qmax: -0.0503
# | Reward: -235 | Episode: 939 | Qmax: -0.0473
# | Reward: -237 | Episode: 940 | Qmax: -0.0499
# | Reward: -1 | Episode: 941 | Qmax: -0.0517
# | Reward: -733 | Episode: 942 | Qmax: -0.0513
# | Reward: -913 | Episode: 943 | Qmax: -0.0521
# | Reward: -247 | Episode: 944 | Qmax: -0.0505
# | Reward: -244 | Episode: 945 | Qmax: -0.0467
# | Reward: -124 | Episode: 946 | Qmax: -0.0460
# | Reward: -115 | Episode: 947 | Qmax: -0.0465
# | Reward: -3 | Episode: 948 | Qmax: -0.0463
# | Reward: -130 | Episode: 949 | Qmax: -0.0421
# | Reward: -242 | Episode: 950 | Qmax: -0.0411
# | Reward: -124 | Episode: 951 | Qmax: -0.0422
# | Reward: -367 | Episode: 952 | Qmax: -0.0438
# | Reward: -117 | Episode: 953 | Qmax: -0.0449
# | Reward: -362 | Episode: 954 | Qmax: -0.0420
# | Reward: -232 | Episode: 955 | Qmax: -0.0426
# | Reward: -126 | Episode: 956 | Qmax: -0.0399
# | Reward: -495 | Episode: 957 | Qmax: -0.0379
# | Reward: -117 | Episode: 958 | Qmax: -0.0424
# | Reward: -122 | Episode: 959 | Qmax: -0.0447
# | Reward: -241 | Episode: 960 | Qmax: -0.0421
# | Reward: -121 | Episode: 961 | Qmax: -0.0433
# | Reward: -400 | Episode: 962 | Qmax: -0.0461
# | Reward: -124 | Episode: 963 | Qmax: -0.0478
# | Reward: -243 | Episode: 964 | Qmax: -0.0463
# | Reward: -120 | Episode: 965 | Qmax: -0.0436
# | Reward: -249 | Episode: 966 | Qmax: -0.0447
# | Reward: -379 | Episode: 967 | Qmax: -0.0440
# | Reward: -128 | Episode: 968 | Qmax: -0.0412
# | Reward: -246 | Episode: 969 | Qmax: -0.0409
# | Reward: -126 | Episode: 970 | Qmax: -0.0425
# | Reward: -618 | Episode: 971 | Qmax: -0.0428
# | Reward: -376 | Episode: 972 | Qmax: -0.0415
# | Reward: -286 | Episode: 973 | Qmax: -0.0390
# | Reward: -376 | Episode: 974 | Qmax: -0.0408
# | Reward: -298 | Episode: 975 | Qmax: -0.0402
# | Reward: -5 | Episode: 976 | Qmax: -0.0394
# | Reward: -497 | Episode: 977 | Qmax: -0.0422
# | Reward: -610 | Episode: 978 | Qmax: -0.0403
# | Reward: -623 | Episode: 979 | Qmax: -0.0391
# | Reward: -496 | Episode: 980 | Qmax: -0.0397
# | Reward: -533 | Episode: 981 | Qmax: -0.0396
# | Reward: -597 | Episode: 982 | Qmax: -0.0372
# | Reward: -377 | Episode: 983 | Qmax: -0.0321
# | Reward: -231 | Episode: 984 | Qmax: -0.0359
# | Reward: -241 | Episode: 985 | Qmax: -0.0363
# | Reward: -118 | Episode: 986 | Qmax: -0.0373
# | Reward: -124 | Episode: 987 | Qmax: -0.0329
# | Reward: -117 | Episode: 988 | Qmax: -0.0368
# | Reward: -125 | Episode: 989 | Qmax: -0.0305
# | Reward: -123 | Episode: 990 | Qmax: -0.0329
# | Reward: -125 | Episode: 991 | Qmax: -0.0330
# | Reward: -240 | Episode: 992 | Qmax: -0.0368
# | Reward: -382 | Episode: 993 | Qmax: -0.0295
# | Reward: -410 | Episode: 994 | Qmax: -0.0357
# | Reward: -245 | Episode: 995 | Qmax: -0.0400
# | Reward: -355 | Episode: 996 | Qmax: -0.0392
# | Reward: -5 | Episode: 997 | Qmax: -0.0415
# | Reward: -240 | Episode: 998 | Qmax: -0.0412
# | Reward: -476 | Episode: 999 | Qmax: -0.0368
# | Reward: -732 | Episode: 1000 | Qmax: -0.0384
# | Reward: -618 | Episode: 1001 | Qmax: -0.0461
# | Reward: -259 | Episode: 1002 | Qmax: -0.0457
# ...
# | Reward: -496 | Episode: 1083 | Qmax: -0.0408
# | Reward: -254 | Episode: 1084 | Qmax: -0.0413
# | Reward: -237 | Episode: 1085 | Qmax: -0.0436
# | Reward: -1 | Episode: 1086 | Qmax: -0.0434
# | Reward: -236 | Episode: 1087 | Qmax: -0.0460
# | Reward: -120 | Episode: 1088 | Qmax: -0.0422
# | Reward: -1 | Episode: 1089 | Qmax: -0.0464
# | Reward: -237 | Episode: 1090 | Qmax: -0.0497
# | Reward: -423 | Episode: 1091 | Qmax: -0.0517
# | Reward: -125 | Episode: 1092 | Qmax: -0.0483
# | Reward: -130 | Episode: 1093 | Qmax: -0.0495
# | Reward: -5 | Episode: 1094 | Qmax: -0.0553
# | Reward: -119 | Episode: 1095 | Qmax: -0.0592
# | Reward: -240 | Episode: 1096 | Qmax: -0.0602
# | Reward: -3 | Episode: 1097 | Qmax: -0.0590
# | Reward: -247 | Episode: 1098 | Qmax: -0.0555
# | Reward: -2 | Episode: 1099 | Qmax: -0.0582
# | Reward: -129 | Episode: 1100 | Qmax: -0.0606
# | Reward: -245 | Episode: 1101 | Qmax: -0.0617
# | Reward: -309 | Episode: 1102 | Qmax: -0.0629
# | Reward: -243 | Episode: 1103 | Qmax: -0.0676
# | Reward: -128 | Episode: 1104 | Qmax: -0.0714
# | Reward: -238 | Episode: 1105 | Qmax: -0.0708
# | Reward: -379 | Episode: 1106 | Qmax: -0.0667
# | Reward: -299 | Episode: 1107 | Qmax: -0.0656
# | Reward: -631 | Episode: 1108 | Qmax: -0.0706
# | Reward: -130 | Episode: 1109 | Qmax: -0.0743
# | Reward: -241 | Episode: 1110 | Qmax: -0.0707
# | Reward: -1 | Episode: 1111 | Qmax: -0.0696
# | Reward: -2 | Episode: 1112 | Qmax: -0.0687
# | Reward: -251 | Episode: 1113 | Qmax: -0.0626
# | Reward: -374 | Episode: 1114 | Qmax: -0.0619
# | Reward: -126 | Episode: 1115 | Qmax: -0.0634
# | Reward: -134 | Episode: 1116 | Qmax: -0.0622
# | Reward: -116 | Episode: 1117 | Qmax: -0.0620
# | Reward: -345 | Episode: 1118 | Qmax: -0.0626
# | Reward: -122 | Episode: 1119 | Qmax: -0.0691
# | Reward: -326 | Episode: 1120 | Qmax: -0.0721
# | Reward: -123 | Episode: 1121 | Qmax: -0.0703
# | Reward: -387 | Episode: 1122 | Qmax: -0.0742
# | Reward: -124 | Episode: 1123 | Qmax: -0.0793
# | Reward: -1 | Episode: 1124 | Qmax: -0.0785
# | Reward: -122 | Episode: 1125 | Qmax: -0.0745
# | Reward: -242 | Episode: 1126 | Qmax: -0.0776
# | Reward: -119 | Episode: 1127 | Qmax: -0.0813
# | Reward: -127 | Episode: 1128 | Qmax: -0.0708
# | Reward: -1 | Episode: 1129 | Qmax: -0.0902
# | Reward: -201 | Episode: 1130 | Qmax: -0.0923
# | Reward: -254 | Episode: 1131 | Qmax: -0.0870
# | Reward: -707 | Episode: 1132 | Qmax: -0.0915
# | Reward: -743 | Episode: 1133 | Qmax: -0.0921
# | Reward: -253 | Episode: 1134 | Qmax: -0.0921
# | Reward: -126 | Episode: 1135 | Qmax: -0.1012
# | Reward: -123 | Episode: 1136 | Qmax: -0.1025
# | Reward: -129 | Episode: 1137 | Qmax: -0.1060
# | Reward: -3 | Episode: 1138 | Qmax: -0.1045
# | Reward: -3 | Episode: 1139 | Qmax: -0.1023
# | Reward: -236 | Episode: 1140 | Qmax: -0.1045
# | Reward: -278 | Episode: 1141 | Qmax: -0.1038
# | Reward: -239 | Episode: 1142 | Qmax: -0.1090
# | Reward: -117 | Episode: 1143 | Qmax: -0.1097
# | Reward: -115 | Episode: 1144 | Qmax: -0.1096
# | Reward: -115 | Episode: 1145 | Qmax: -0.1071
# | Reward: -117 | Episode: 1146 | Qmax: -0.1092
# | Reward: -1 | Episode: 1147 | Qmax: -0.1106
# | Reward: -118 | Episode: 1148 | Qmax: -0.1158
# | Reward: -337 | Episode: 1149 | Qmax: -0.1166
# | Reward: -119 | Episode: 1150 | Qmax: -0.1151
# | Reward: -119 | Episode: 1151 | Qmax: -0.1163
# | Reward: -126 | Episode: 1152 | Qmax: -0.1164
# | Reward: -246 | Episode: 1153 | Qmax: -0.1094
# | Reward: -330 | Episode: 1154 | Qmax: -0.1111
# | Reward: -3 | Episode: 1155 | Qmax: -0.1158
# | Reward: -1 | Episode: 1156 | Qmax: -0.1153
# | Reward: -362 | Episode: 1157 | Qmax: -0.1157
# | Reward: -125 | Episode: 1158 | Qmax: -0.1131
# | Reward: -128 | Episode: 1159 | Qmax: -0.1138
# | Reward: -244 | Episode: 1160 | Qmax: -0.1121
# | Reward: -130 | Episode: 1161 | Qmax: -0.1156
# | Reward: -246 | Episode: 1162 | Qmax: -0.1178
# | Reward: -331 | Episode: 1163 | Qmax: -0.1173
# | Reward: -246 | Episode: 1164 | Qmax: -0.1184
# | Reward: -122 | Episode: 1165 | Qmax: -0.1195
# | Reward: -264 | Episode: 1166 | Qmax: -0.1201
# | Reward: -316 | Episode: 1167 | Qmax: -0.1208
# | Reward: -375 | Episode: 1168 | Qmax: -0.1212
# | Reward: -304 | Episode: 1169 | Qmax: -0.1264
# | Reward: -861 | Episode: 1170 | Qmax: -0.1284
# | Reward: -766 | Episode: 1171 | Qmax: -0.1283
# | Reward: -616 | Episode: 1172 | Qmax: -0.1305
# | Reward: -127 | Episode: 1173 | Qmax: -0.1288
# | Reward: -231 | Episode: 1174 | Qmax: -0.1253
# | Reward: -4 | Episode: 1175 | Qmax: -0.1260
# | Reward: -751 | Episode: 1176 | Qmax: -0.1270
# | Reward: -507 | Episode: 1177 | Qmax: -0.1303
# | Reward: -116 | Episode: 1178 | Qmax: -0.1313
# | Reward: -246 | Episode: 1179 | Qmax: -0.1327
# | Reward: -317 | Episode: 1180 | Qmax: -0.1352
# | Reward: -226 | Episode: 1181 | Qmax: -0.1402
# | Reward: -117 | Episode: 1182 | Qmax: -0.1423
# | Reward: -120 | Episode: 1183 | Qmax: -0.1392
# | Reward: -370 | Episode: 1184 | Qmax: -0.1373
# | Reward: -123 | Episode: 1185 | Qmax: -0.1384
# | Reward: -123 | Episode: 1186 | Qmax: -0.1431
# | Reward: -244 | Episode: 1187 | Qmax: -0.1456
# | Reward: -243 | Episode: 1188 | Qmax: -0.1520
# | Reward: -2 | Episode: 1189 | Qmax: -0.1556
# | Reward: -119 | Episode: 1190 | Qmax: -0.1571
# | Reward: -124 | Episode: 1191 | Qmax: -0.1568
# | Reward: -123 | Episode: 1192 | Qmax: -0.1582
# | Reward: -125 | Episode: 1193 | Qmax: -0.1576
# | Reward: -249 | Episode: 1194 | Qmax: -0.1578
# | Reward: -264 | Episode: 1195 | Qmax: -0.1544
# | Reward: -122 | Episode: 1196 | Qmax: -0.1550
# | Reward: -129 | Episode: 1197 | Qmax: -0.1589
# | Reward: -123 | Episode: 1198 | Qmax: -0.1634
# | Reward: -118 | Episode: 1199 | Qmax: -0.1698
# | Reward: -125 | Episode: 1200 | Qmax: -0.1687
# | Reward: -127 | Episode: 1201 | Qmax: -0.1662
# | Reward: -248 | Episode: 1202 | Qmax: -0.1732
# | Reward: -3 | Episode: 1203 | Qmax: -0.1729
# | Reward: -124 | Episode: 1204 | Qmax: -0.1772
# | Reward: -252 | Episode: 1205 | Qmax: -0.1837
# | Reward: -240 | Episode: 1206 | Qmax: -0.1822
# | Reward: -125 | Episode: 1207 | Qmax: -0.1783
# | Reward: -121 | Episode: 1208 | Qmax: -0.1751
# | Reward: -239 | Episode: 1209 | Qmax: -0.1807
# | Reward: -126 | Episode: 1210 | Qmax: -0.1865
# | Reward: -231 | Episode: 1211 | Qmax: -0.1823
# | Reward: -254 | Episode: 1212 | Qmax: -0.1762
# | Reward: -119 | Episode: 1213 | Qmax: -0.1767
# | Reward: -122 | Episode: 1214 | Qmax: -0.1829
# | Reward: -121 | Episode: 1215 | Qmax: -0.1913
# | Reward: -241 | Episode: 1216 | Qmax: -0.1858
# | Reward: -122 | Episode: 1217 | Qmax: -0.1823
# | Reward: -1 | Episode: 1218 | Qmax: -0.1877
# | Reward: -119 | Episode: 1219 | Qmax: -0.1908
# | Reward: -246 | Episode: 1220 | Qmax: -0.1912
# | Reward: 0 | Episode: 1221 | Qmax: -0.1940
# | Reward: -122 | Episode: 1222 | Qmax: -0.1936
# | Reward: -120 | Episode: 1223 | Qmax: -0.1906
# | Reward: -227 | Episode: 1224 | Qmax: -0.1951
# | Reward: -125 | Episode: 1225 | Qmax: -0.1927
# | Reward: -247 | Episode: 1226 | Qmax: -0.1917
# | Reward: -255 | Episode: 1227 | Qmax: -0.1938
# | Reward: -502 | Episode: 1228 | Qmax: -0.1932
# | Reward: -122 | Episode: 1229 | Qmax: -0.1928
# | Reward: -503 | Episode: 1230 | Qmax: -0.1882
# | Reward: -127 | Episode: 1231 | Qmax: -0.2025
# | Reward: -117 | Episode: 1232 | Qmax: -0.2039
# | Reward: -115 | Episode: 1233 | Qmax: -0.2009
# | Reward: -120 | Episode: 1234 | Qmax: -0.1932
# | Reward: -356 | Episode: 1235 | Qmax: -0.2009
# | Reward: -121 | Episode: 1236 | Qmax: -0.1970
# | Reward: -121 | Episode: 1237 | Qmax: -0.1998
# | Reward: -127 | Episode: 1238 | Qmax: -0.2037
# | Reward: -238 | Episode: 1239 | Qmax: -0.1996
# | Reward: -239 | Episode: 1240 | Qmax: -0.2040
# | Reward: -334 | Episode: 1241 | Qmax: -0.2097
# | Reward: -129 | Episode: 1242 | Qmax: -0.2078
# | Reward: -2 | Episode: 1243 | Qmax: -0.2100
# | Reward: -123 | Episode: 1244 | Qmax: -0.2096
# | Reward: -232 | Episode: 1245 | Qmax: -0.2069
# | Reward: -117 | Episode: 1246 | Qmax: -0.2104
# | Reward: -119 | Episode: 1247 | Qmax: -0.2116
# | Reward: -116 | Episode: 1248 | Qmax: -0.2107
# | Reward: -242 | Episode: 1249 | Qmax: -0.2126
# | Reward: -125 | Episode: 1250 | Qmax: -0.2053
# | Reward: -122 | Episode: 1251 | Qmax: -0.2150
# | Reward: -128 | Episode: 1252 | Qmax: -0.2109
# | Reward: -121 | Episode: 1253 | Qmax: -0.1997
# | Reward: -240 | Episode: 1254 | Qmax: -0.1814
# | Reward: -122 | Episode: 1255 | Qmax: -0.1633
# | Reward: -116 | Episode: 1256 | Qmax: -0.1969
# | Reward: -125 | Episode: 1257 | Qmax: -0.1985
# | Reward: -126 | Episode: 1258 | Qmax: -0.2092
# | Reward: -116 | Episode: 1259 | Qmax: -0.1868
# | Reward: -128 | Episode: 1260 | Qmax: -0.2048
# | Reward: -232 | Episode: 1261 | Qmax: -0.2117
# | Reward: -236 | Episode: 1262 | Qmax: -0.2047
# | Reward: -235 | Episode: 1263 | Qmax: -0.1905
# | Reward: -238 | Episode: 1264 | Qmax: -0.1648
# | Reward: -334 | Episode: 1265 | Qmax: -0.1337
# | Reward: -122 | Episode: 1266 | Qmax: -0.0914
# | Reward: -238 | Episode: 1267 | Qmax: -0.1324
# | Reward: -123 | Episode: 1268 | Qmax: -0.1397
# | Reward: -244 | Episode: 1269 | Qmax: -0.1929
# | Reward: -124 | Episode: 1270 | Qmax: -0.1931
# | Reward: -386 | Episode: 1271 | Qmax: -0.1514
# | Reward: -244 | Episode: 1272 | Qmax: -0.1603
# | Reward: -251 | Episode: 1273 | Qmax: -0.0877
# | Reward: -2 | Episode: 1274 | Qmax: -0.0892
# | Reward: -241 | Episode: 1275 | Qmax: -0.0584
# | Reward: -236 | Episode: 1276 | Qmax: 0.0127
# | Reward: -114 | Episode: 1277 | Qmax: 0.0454
# | Reward: -357 | Episode: 1278 | Qmax: 0.1541
# | Reward: -125 | Episode: 1279 | Qmax: 0.2763
# | Reward: -237 | Episode: 1280 | Qmax: 0.7593
# | Reward: -236 | Episode: 1281 | Qmax: 1.5324
# | Reward: -126 | Episode: 1282 | Qmax: 2.5044
# | Reward: -130 | Episode: 1283 | Qmax: 3.6430
# | Reward: -130 | Episode: 1284 | Qmax: 4.4167
# | Reward: -132 | Episode: 1285 | Qmax: 4.8892
# | Reward: -10 | Episode: 1286 | Qmax: 5.0626
# | Reward: -258 | Episode: 1287 | Qmax: 5.2405
# | Reward: -7 | Episode: 1288 | Qmax: 4.9682
# | Reward: -128 | Episode: 1289 | Qmax: 4.5020
# | Reward: -123 | Episode: 1290 | Qmax: 4.1247
# | Reward: -130 | Episode: 1291 | Qmax: 3.7289
# | Reward: -245 | Episode: 1292 | Qmax: 3.3923
# | Reward: -133 | Episode: 1293 | Qmax: 3.2177
# | Reward: -127 | Episode: 1294 | Qmax: 3.0174
# | Reward: -129 | Episode: 1295 | Qmax: 2.8187
# | Reward: -5 | Episode: 1296 | Qmax: 2.5203
# | Reward: -121 | Episode: 1297 | Qmax: 2.4985
# | Reward: -250 | Episode: 1298 | Qmax: 2.4328
# | Reward: -132 | Episode: 1299 | Qmax: 2.1575
# | Reward: -9 | Episode: 1300 | Qmax: 2.0629
# | Reward: -132 | Episode: 1301 | Qmax: 1.9563
# | Reward: -632 | Episode: 1302 | Qmax: 1.7609
# | Reward: -370 | Episode: 1303 | Qmax: 1.6991
# | Reward: -253 | Episode: 1304 | Qmax: 1.5012
# | Reward: -3 | Episode: 1305 | Qmax: 1.4330
# | Reward: -246 | Episode: 1306 | Qmax: 1.3812
# | Reward: -8 | Episode: 1307 | Qmax: 1.3772
# | Reward: -9 | Episode: 1308 | Qmax: 1.4097
# | Reward: -355 | Episode: 1309 | Qmax: 1.4493
# | Reward: -126 | Episode: 1310 | Qmax: 1.4334
# | Reward: -350 | Episode: 1311 | Qmax: 1.3980
# | Reward: -124 | Episode: 1312 | Qmax: 1.2960
# | Reward: -250 | Episode: 1313 | Qmax: 1.1786
# | Reward: -125 | Episode: 1314 | Qmax: 1.1522
# | Reward: -365 | Episode: 1315 | Qmax: 1.1941
# | Reward: -237 | Episode: 1316 | Qmax: 1.2361
# | Reward: -9 | Episode: 1317 | Qmax: 1.2672
# | Reward: -128 | Episode: 1318 | Qmax: 1.4361
# | Reward: -10 | Episode: 1319 | Qmax: 1.4334
# | Reward: -123 | Episode: 1320 | Qmax: 1.5376
# | Reward: -258 | Episode: 1321 | Qmax: 1.5858
# | Reward: -124 | Episode: 1322 | Qmax: 1.6455
# | Reward: -131 | Episode: 1323 | Qmax: 1.6395
# | Reward: -481 | Episode: 1324 | Qmax: 1.4835
# | Reward: -120 | Episode: 1325 | Qmax: 1.5509
# | Reward: -261 | Episode: 1326 | Qmax: 1.5371
# | Reward: -126 | Episode: 1327 | Qmax: 1.3726
# | Reward: -375 | Episode: 1328 | Qmax: 1.3152
# | Reward: -123 | Episode: 1329 | Qmax: 1.1496
# | Reward: -127 | Episode: 1330 | Qmax: 1.1073
# | Reward: -244 | Episode: 1331 | Qmax: 1.0860
# | Reward: -128 | Episode: 1332 | Qmax: 0.9639
# | Reward: -127 | Episode: 1333 | Qmax: 0.8921
# | Reward: -252 | Episode: 1334 | Qmax: 0.8424
# | Reward: -123 | Episode: 1335 | Qmax: 0.7917
# | Reward: -122 | Episode: 1336 | Qmax: 0.6587
# | Reward: -234 | Episode: 1337 | Qmax: 0.6233
# | Reward: -125 | Episode: 1338 | Qmax: 0.5877
# | Reward: -413 | Episode: 1339 | Qmax: 0.5025
# | Reward: -248 | Episode: 1340 | Qmax: 0.4436
# | Reward: -482 | Episode: 1341 | Qmax: 0.3847
# | Reward: -227 | Episode: 1342 | Qmax: 0.3162
# | Reward: -253 | Episode: 1343 | Qmax: 0.2565
# | Reward: -241 | Episode: 1344 | Qmax: 0.3061
# | Reward: -229 | Episode: 1345 | Qmax: 0.3411
# | Reward: -1 | Episode: 1346 | Qmax: 0.2591
# | Reward: -126 | Episode: 1347 | Qmax: 0.2126
# | Reward: -2 | Episode: 1348 | Qmax: 0.2710
# | Reward: -126 | Episode: 1349 | Qmax: 0.2382
# | Reward: -243 | Episode: 1350 | Qmax: 0.2660
# | Reward: -120 | Episode: 1351 | Qmax: 0.4326
# | Reward: -125 | Episode: 1352 | Qmax: 0.4585
# | Reward: -255 | Episode: 1353 | Qmax: 0.5495
# | Reward: -126 | Episode: 1354 | Qmax: 0.6928
# | Reward: -126 | Episode: 1355 | Qmax: 0.6763
# | Reward: -3 | Episode: 1356 | Qmax: 0.5764
# | Reward: -376 | Episode: 1357 | Qmax: 0.7036
# | Reward: -633 | Episode: 1358 | Qmax: 0.8681
# | Reward: -746 | Episode: 1359 | Qmax: 0.9925
# | Reward: -248 | Episode: 1360 | Qmax: 1.1165
# | Reward: -126 | Episode: 1361 | Qmax: 1.2939
# | Reward: -3 | Episode: 1362 | Qmax: 1.2115
# | Reward: -368 | Episode: 1363 | Qmax: 1.5150
# | Reward: -833 | Episode: 1364 | Qmax: 1.5845
# | Reward: -745 | Episode: 1365 | Qmax: 1.4853
# | Reward: -645 | Episode: 1366 | Qmax: 1.4673
# | Reward: -261 | Episode: 1367 | Qmax: 1.8841
# | Reward: -129 | Episode: 1368 | Qmax: 2.2975
# | Reward: -7 | Episode: 1369 | Qmax: 2.6951
# | Reward: -238 | Episode: 1370 | Qmax: 3.1418
# | Reward: -245 | Episode: 1371 | Qmax: 3.6691
# | Reward: -8 | Episode: 1372 | Qmax: 4.5938
# | Reward: -126 | Episode: 1373 | Qmax: 5.2154
# | Reward: -553 | Episode: 1374 | Qmax: 6.0947
# | Reward: -251 | Episode: 1375 | Qmax: 6.6623
# | Reward: -486 | Episode: 1376 | Qmax: 7.8453
# | Reward: -3 | Episode: 1377 | Qmax: 8.3600
# | Reward: -125 | Episode: 1378 | Qmax: 9.2173
# | Reward: -122 | Episode: 1379 | Qmax: 9.9614
# | Reward: -250 | Episode: 1380 | Qmax: 10.5829
# | Reward: -125 | Episode: 1381 | Qmax: 10.6686
# | Reward: -121 | Episode: 1382 | Qmax: 10.6560
# | Reward: -344 | Episode: 1383 | Qmax: 10.5299
# | Reward: -117 | Episode: 1384 | Qmax: 10.4590
# | Reward: -239 | Episode: 1385 | Qmax: 10.5264
# | Reward: -122 | Episode: 1386 | Qmax: 10.4393
# | Reward: -236 | Episode: 1387 | Qmax: 10.1687
# | Reward: -3 | Episode: 1388 | Qmax: 10.0076
# | Reward: -127 | Episode: 1389 | Qmax: 9.4346
# | Reward: -248 | Episode: 1390 | Qmax: 8.8852
# | Reward: -255 | Episode: 1391 | Qmax: 8.8460
# | Reward: -122 | Episode: 1392 | Qmax: 8.6850
# | Reward: -372 | Episode: 1393 | Qmax: 8.4262
# | Reward: -619 | Episode: 1394 | Qmax: 8.0135
# | Reward: -506 | Episode: 1395 | Qmax: 7.9012
# | Reward: -626 | Episode: 1396 | Qmax: 7.7399
# | Reward: -623 | Episode: 1397 | Qmax: 7.8350
# | Reward: -344 | Episode: 1398 | Qmax: 7.4041
# | Reward: -314 | Episode: 1399 | Qmax: 7.1006
# | Reward: -240 | Episode: 1400 | Qmax: 7.0967
# | Reward: -123 | Episode: 1401 | Qmax: 6.8313
# | Reward: -234 | Episode: 1402 | Qmax: 6.9928
# | Reward: -128 | Episode: 1403 | Qmax: 7.0041
# | Reward: -127 | Episode: 1404 | Qmax: 6.8199
# | Reward: -120 | Episode: 1405 | Qmax: 6.9421
# | Reward: -241 | Episode: 1406 | Qmax: 7.3299
# | Reward: -149 | Episode: 1407 | Qmax: 7.2125
# | Reward: -850 | Episode: 1408 | Qmax: 7.2588
# | Reward: -730 | Episode: 1409 | Qmax: 6.7613
# | Reward: -232 | Episode: 1410 | Qmax: 6.7689
# | Reward: -222 | Episode: 1411 | Qmax: 6.7508
# | Reward: -251 | Episode: 1412 | Qmax: 6.7774
# | Reward: -569 | Episode: 1413 | Qmax: 6.3455
# | Reward: -379 | Episode: 1414 | Qmax: 6.2072
# | Reward: -374 | Episode: 1415 | Qmax: 6.4732
# | Reward: -386 | Episode: 1416 | Qmax: 6.3163
# | Reward: -6 | Episode: 1417 | Qmax: 6.0071
# | Reward: -3 | Episode: 1418 | Qmax: 5.8521
# | Reward: -125 | Episode: 1419 | Qmax: 5.7391
# | Reward: -128 | Episode: 1420 | Qmax: 5.5170
# | Reward: -358 | Episode: 1421 | Qmax: 5.6044
# | Reward: -4 | Episode: 1422 | Qmax: 5.6323
# | Reward: -250 | Episode: 1423 | Qmax: 5.5003
# | Reward: -256 | Episode: 1424 | Qmax: 5.4993
# | Reward: 0 | Episode: 1425 | Qmax: 5.5675
# | Reward: -228 | Episode: 1426 | Qmax: 6.3066
# | Reward: -114 | Episode: 1427 | Qmax: 7.3199
